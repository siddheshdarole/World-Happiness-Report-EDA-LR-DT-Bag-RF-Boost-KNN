# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import plotly.express as px
import plotly.graph_objs as go
import statsmodels.api as sm
import math

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# %matplotlib inline

# %%
df_2015 = pd.read_csv("../input/world-happiness/2015.csv")
df_2016 = pd.read_csv("../input/world-happiness/2016.csv")
df_2017 = pd.read_csv("../input/world-happiness/2017.csv")
df_2018 = pd.read_csv("../input/world-happiness/2018.csv")
df_2019 = pd.read_csv("../input/world-happiness/2019.csv")

# %% [markdown]
# # Cleaning and Merging of data from each year:
# We have five different files for every from 2015 - 2019. Lets see what are all the columns in every dataset, look into which columns we would required for EDA. We will look for each year, include additional column to identify from the year and eventually merge the data to final dataset for our analysis.

# %% [markdown]
# #### Year 2015

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Use Year 2015 columns in our analysis and insert another column for year. 

df_2015_temp = df_2015.filter(['Happiness Rank', 'Country', 'Region','Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)','Generosity', 
                        'Happiness Score' ])

# %%
df_2015_temp.insert(0, "Year", 2015)

# %% [markdown]
# #### Year 2016

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
# Use Year 2016 columns in our analysis and insert another column for year. 

df_2016_temp = df_2016.filter(['Happiness Rank','Country', 'Region','Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity',
                        'Happiness Score'])

# %%
df_2016_temp.insert(0, "Year", 2016)

# %% [markdown]
# ####  Year 2017

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df_2017.rename(columns = {'Happiness.Rank':'Happiness Rank',
                          'Happiness.Score':'Happiness Score',
                          'Economy..GDP.per.Capita.' : 'Economy (GDP per Capita)',
                          'Health..Life.Expectancy.' : 'Health (Life Expectancy)',
                          'Trust..Government.Corruption.' : 'Trust (Government Corruption)',
                           }, inplace = True)

# %%
# Use Year 2017 columns in our analysis and insert another column for year. 

df_2017_temp = df_2017.filter(['Happiness Rank','Country','Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity',
                        'Happiness Score'])

# %%
df_2017_temp.insert(0, "Year", 2017)

# %% [markdown]
# #### Year 2018

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
df_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df_2018.rename(columns = {'Overall rank' : 'Happiness Rank',
                          'Country or region' : 'Country',
                          'Score' : 'Happiness Score',
                          'Social support' : 'Family',
                          'GDP per capita' : 'Economy (GDP per Capita)',
                          'Healthy life expectancy' : 'Health (Life Expectancy)',
                          'Freedom to make life choices' :'Freedom',
                          'Perceptions of corruption' : 'Trust (Government Corruption)'
                          }, inplace = True)

# %%
# Use Year 2018 columns in our analysis and insert another column for year. 

df_2018_temp = df_2018.filter(['Happiness Rank','Country','Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity',
                        'Happiness Score'])

# %%
df_2018_temp.insert(0, "Year", 2018)

# %% [markdown]
# ####  Year 2019

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df_2019.rename(columns = {'Overall rank' : 'Happiness Rank',
                          'Country or region' : 'Country',
                          'Score' : 'Happiness Score',
                          'Social support' : 'Family',
                          'GDP per capita' : 'Economy (GDP per Capita)',
                          'Healthy life expectancy' : 'Health (Life Expectancy)',
                          'Freedom to make life choices' :'Freedom',
                          'Perceptions of corruption' : 'Trust (Government Corruption)'
                          }, inplace = True)

# %%
# Use Year 2019 columns in our analysis and insert another column for year. 

df_2019_temp = df_2019.filter(['Happiness Rank','Country','Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity',
                        'Happiness Score'])

# %%
df_2019_temp.insert(0, "Year", 2019)

# %%
df_2016_temp
# Out:
#      Year  Happiness Rank      Country                           Region  \
# 0    2016               1      Denmark                   Western Europe
# 1    2016               2  Switzerland                   Western Europe
# 2    2016               3      Iceland                   Western Europe
# 3    2016               4       Norway                   Western Europe
# 4    2016               5      Finland                   Western Europe
# ..    ...             ...          ...                              ...
# 152  2016             153        Benin               Sub-Saharan Africa
# 153  2016             154  Afghanistan                    Southern Asia
# 154  2016             155         Togo               Sub-Saharan Africa
# 155  2016             156        Syria  Middle East and Northern Africa
# 156  2016             157      Burundi               Sub-Saharan Africa
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.44178  1.16374                   0.79504  0.57941
# 1                     1.52733  1.14524                   0.86303  0.58557
# 2                     1.42666  1.18326                   0.86733  0.56624
# 3                     1.57744  1.12690                   0.79579  0.59609
# 4                     1.40598  1.13464                   0.81091  0.57104
# ..                        ...      ...                       ...      ...
# 152                   0.39499  0.10419                   0.21028  0.39747
# 153                   0.38227  0.11037                   0.17344  0.16430
# 154                   0.28123  0.00000                   0.24811  0.34678
# 155                   0.74719  0.14866                   0.62994  0.06912
# 156                   0.06831  0.23442                   0.15747  0.04320
#
#      Trust (Government Corruption)  Generosity  Happiness Score
# 0                          0.44453     0.36171            7.526
# 1                          0.41203     0.28083            7.509
# 2                          0.14975     0.47678            7.501
# 3                          0.35776     0.37895            7.498
# 4                          0.41004     0.25492            7.413
# ..                             ...         ...              ...
# 152                        0.06681     0.20180            3.484
# 153                        0.07112     0.31268            3.360
# 154                        0.11587     0.17517            3.303
# 155                        0.17233     0.48397            3.069
# 156                        0.09419     0.20290            2.905
#
# [157 rows x 11 columns]

# %%
print ('Numbers of rows and columns in year 2015 :', df_2015_temp.shape)
print ('Numbers of rows and columns in year 2016 :', df_2016_temp.shape)
print ('Numbers of rows and columns in year 2017 :', df_2017_temp.shape)
print ('Numbers of rows and columns in year 2018 :', df_2018_temp.shape)
print ('Numbers of rows and columns in year 2019 :', df_2019_temp.shape)
# Out:
# Numbers of rows and columns in year 2015 : (158, 11)
# Numbers of rows and columns in year 2016 : (157, 11)
# Numbers of rows and columns in year 2017 : (155, 10)
# Numbers of rows and columns in year 2018 : (156, 10)
# Numbers of rows and columns in year 2019 : (156, 10)

# %% [markdown]
# #### 6. Merge Data.

# %%
# Merge Data so that we can get Region in each missing database. This can be done using comparing two columns from 
# to different databases and merging it together and dropping all the columns.

df_2017_temp = df_2017_temp.merge(df_2016_temp,left_on = 'Country', right_on = 'Country', how = 'inner')
df_2018_temp = df_2018_temp.merge(df_2016_temp,left_on = 'Country', right_on = 'Country', how = 'inner')
df_2019_temp = df_2019_temp.merge(df_2015_temp,left_on = 'Country', right_on = 'Country', how = 'inner')

# %% [markdown]
# Year 17,18 and 19 do not have Region column, as Region column can be used for EDA. So with the help of year 2015 and 2016 we will merge the data of 17,18,19 on the bases of Country.

# %%
print(df_2017_temp.columns)
print(df_2018_temp.columns)
print(df_2019_temp.columns)
# Out:
# Index(['Year_x', 'Happiness Rank_x', 'Country', 'Economy (GDP per Capita)_x',
#        'Family_x', 'Health (Life Expectancy)_x', 'Freedom_x',
#        'Trust (Government Corruption)_x', 'Generosity_x', 'Happiness Score_x',
#        'Year_y', 'Happiness Rank_y', 'Region', 'Economy (GDP per Capita)_y',
#        'Family_y', 'Health (Life Expectancy)_y', 'Freedom_y',
#        'Trust (Government Corruption)_y', 'Generosity_y', 'Happiness Score_y'],
#       dtype='object')
# Index(['Year_x', 'Happiness Rank_x', 'Country', 'Economy (GDP per Capita)_x',
#        'Family_x', 'Health (Life Expectancy)_x', 'Freedom_x',
#        'Trust (Government Corruption)_x', 'Generosity_x', 'Happiness Score_x',
#        'Year_y', 'Happiness Rank_y', 'Region', 'Economy (GDP per Capita)_y',
#        'Family_y', 'Health (Life Expectancy)_y', 'Freedom_y',
#        'Trust (Government Corruption)_y', 'Generosity_y', 'Happiness Score_y'],
#       dtype='object')
# Index(['Year_x', 'Happiness Rank_x', 'Country', 'Economy (GDP per Capita)_x',
#        'Family_x', 'Health (Life Expectancy)_x', 'Freedom_x',
#        'Trust (Government Corruption)_x', 'Generosity_x', 'Happiness Score_x',
#        'Year_y', 'Happiness Rank_y', 'Region', 'Economy (GDP per Capita)_y',
#        'Family_y', 'Health (Life Expectancy)_y', 'Freedom_y',
#        'Trust (Government Corruption)_y', 'Generosity_y', 'Happiness Score_y'],
#       dtype='object')

# %% [markdown]
# As we have merged the data on inner join on Country, columns of 16 are also getting joined and since the column names of 16 and 17 are same,
# we can see that a suffix has been added to those all the columns.
# _x represents year 17
# _y represents year 16
#
# ### Now to retain our data we will drop and rename _y columns.

# %%
df_2017_temp.drop(columns = ['Year_y', 'Happiness Rank_y','Economy (GDP per Capita)_y',
       'Family_y', 'Health (Life Expectancy)_y', 'Freedom_y',
       'Trust (Government Corruption)_y', 'Generosity_y', 'Happiness Score_y'], inplace = True)

# %%
df_2018_temp.drop(columns = ['Year_y','Happiness Rank_y','Economy (GDP per Capita)_y',
       'Family_y', 'Health (Life Expectancy)_y', 'Freedom_y','Year_y',
       'Trust (Government Corruption)_y', 'Generosity_y', 'Happiness Score_y'], inplace = True)

# %%
df_2019_temp.drop(columns = ['Year_y', 'Happiness Rank_y','Economy (GDP per Capita)_y',
       'Family_y', 'Health (Life Expectancy)_y', 'Freedom_y',
       'Trust (Government Corruption)_y', 'Generosity_y', 'Happiness Score_y'], inplace = True)

# %%
df_2017_temp.rename(columns = {'Year_x' : 'Year',
                          'Happiness Rank_x' : 'Happiness Rank',
                          'Happiness Score_x':'Happiness Score',
                          'Family_x':'Family',
                          'Economy (GDP per Capita)_x':'Economy (GDP per Capita)',
                          'Health (Life Expectancy)_x': 'Health (Life Expectancy)',
                          'Freedom_x' : 'Freedom',
                          'Trust (Government Corruption)_x': 'Trust (Government Corruption)',
                          'Generosity_x':'Generosity'
                          }, inplace = True)

# %%
df_2018_temp.rename(columns = {'Year_x' : 'Year',
                          'Happiness Rank_x' : 'Happiness Rank',
                          'Happiness Score_x':'Happiness Score',
                          'Family_x':'Family',
                          'Economy (GDP per Capita)_x':'Economy (GDP per Capita)',
                          'Health (Life Expectancy)_x': 'Health (Life Expectancy)',
                          'Freedom_x' : 'Freedom',
                          'Trust (Government Corruption)_x': 'Trust (Government Corruption)',
                          'Generosity_x':'Generosity'
                          }, inplace = True)

# %%
df_2019_temp.rename(columns = {'Year_x' : 'Year',
                          'Happiness Rank_x' : 'Happiness Rank',
                          'Happiness Score_x':'Happiness Score',
                          'Family_x':'Family',
                          'Economy (GDP per Capita)_x':'Economy (GDP per Capita)',
                          'Health (Life Expectancy)_x': 'Health (Life Expectancy)',
                          'Freedom_x' : 'Freedom',
                          'Trust (Government Corruption)_x': 'Trust (Government Corruption)',
                          'Generosity_x':'Generosity'
                          }, inplace = True)

# %% [markdown]
# Now rearranging every data frame.

# %%
df_2015_temp = df_2015.filter(['Year','Country','Region', 'Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', 
                        'Happiness Score', 'Happiness Rank'])

# %%
df_2016_temp = df_2016.filter(['Year','Country','Region', 'Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', 
                        'Happiness Score', 'Happiness Rank'])

# %%
df_2017_temp = df_2017_temp.filter(['Year','Country','Region', 'Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', 
                        'Happiness Score', 'Happiness Rank'])

# %%
df_2018_temp = df_2018_temp.filter(['Year','Country','Region', 'Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', 
                        'Happiness Score', 'Happiness Rank'])

# %%
df_2019_temp = df_2019_temp.filter(['Year','Country','Region', 'Economy (GDP per Capita)','Family',
                        'Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)', 'Generosity', 
                        'Happiness Score', 'Happiness Rank'])

# %%
df_2015_temp.insert(0, "Year", 2015)

# %%
df_2016_temp.insert(0, "Year", 2016)

# %%
# Create dataset including all the data from all the years together.

df_final = pd.concat([df_2015_temp,df_2016_temp,df_2017_temp,df_2018_temp,df_2019_temp], 
                     sort = False, ignore_index=True)

# %%
df_final
# Out:
#      Year                   Country                           Region  \
# 0    2015               Switzerland                   Western Europe
# 1    2015                   Iceland                   Western Europe
# 2    2015                   Denmark                   Western Europe
# 3    2015                    Norway                   Western Europe
# 4    2015                    Canada                    North America
# ..    ...                       ...                              ...
# 760  2019                     Yemen  Middle East and Northern Africa
# 761  2019                    Rwanda               Sub-Saharan Africa
# 762  2019                  Tanzania               Sub-Saharan Africa
# 763  2019               Afghanistan                    Southern Asia
# 764  2019  Central African Republic               Sub-Saharan Africa
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 760                   0.28700  1.16300                   0.46300  0.14300
# 761                   0.35900  0.71100                   0.61400  0.55500
# 762                   0.47600  0.88500                   0.49900  0.41700
# 763                   0.35000  0.51700                   0.36100  0.00000
# 764                   0.02600  0.00000                   0.10500  0.22500
#
#      Trust (Government Corruption)  Generosity  Happiness Score  \
# 0                          0.41978     0.29678            7.587
# 1                          0.14145     0.43630            7.561
# 2                          0.48357     0.34139            7.527
# 3                          0.36503     0.34699            7.522
# 4                          0.32957     0.45811            7.427
# ..                             ...         ...              ...
# 760                        0.07700     0.10800            3.380
# 761                        0.41100     0.21700            3.334
# 762                        0.14700     0.27600            3.231
# 763                        0.02500     0.15800            3.203
# 764                        0.03500     0.23500            3.083
#
#      Happiness Rank
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ..              ...
# 760             151
# 761             152
# 762             153
# 763             154
# 764             155
#
# [765 rows x 11 columns]

# %%
df_final.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Happiness Score', 'Happiness Rank'],
#       dtype='object')

# %%
df_final.isna().sum()
# Out:
# Year                             0
# Country                          0
# Region                           0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    1
# Generosity                       0
# Happiness Score                  0
# Happiness Rank                   0
# dtype: int64

# %%
#identify the NA value

df_final[df_final['Trust (Government Corruption)'].isna()]
# Out:
#      Year               Country                           Region  \
# 484  2018  United Arab Emirates  Middle East and Northern Africa
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 484                     2.096   0.776                      0.67    0.284
#
#      Trust (Government Corruption)  Generosity  Happiness Score  \
# 484                            NaN       0.186            6.774
#
#      Happiness Rank
# 484              20

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           765 non-null    int64
#  1   Country                        765 non-null    object
#  2   Region                         765 non-null    object
#  3   Economy (GDP per Capita)       765 non-null    float64
#  4   Family                         765 non-null    float64
#  5   Health (Life Expectancy)       765 non-null    float64
#  6   Freedom                        765 non-null    float64
#  7   Trust (Government Corruption)  764 non-null    float64
#  8   Generosity                     765 non-null    float64
#  9   Happiness Score                765 non-null    float64
#  10  Happiness Rank                 765 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 65.9+ KB

# %%
#Replace the NaN value with the mean of all values from each year for United Arab Emirates.

df_UAE = df_final[df_final['Country'] == 'United Arab Emirates']
df_UAE
# Out:
#      Year               Country                           Region  \
# 19   2015  United Arab Emirates  Middle East and Northern Africa
# 185  2016  United Arab Emirates  Middle East and Northern Africa
# 335  2017  United Arab Emirates  Middle East and Northern Africa
# 484  2018  United Arab Emirates  Middle East and Northern Africa
# 636  2019  United Arab Emirates  Middle East and Northern Africa
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)   Freedom  \
# 19                   1.427270  1.12575                  0.809250  0.641570
# 185                  1.573520  0.87114                  0.729930  0.562150
# 335                  1.626343  1.26641                  0.726798  0.608345
# 484                  2.096000  0.77600                  0.670000  0.284000
# 636                  1.503000  1.31000                  0.825000  0.598000
#
#      Trust (Government Corruption)  Generosity  Happiness Score  \
# 19                         0.38583    0.264280            6.901
# 185                        0.35561    0.265910            6.573
# 335                        0.32449    0.360942            6.648
# 484                            NaN    0.186000            6.774
# 636                        0.18200    0.262000            6.825
#
#      Happiness Rank
# 19               20
# 185              28
# 335              21
# 484              20
# 636              21

# %%
df_UAE['Trust (Government Corruption)'].mean()  #find mean
# Out:
# 0.3119823909258842

# %%
# replace the value to mean

df_final.fillna(0.311982, inplace=True)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #### Finding Correlation between different columns with Happiness Score.

# %%
plt.figure(figsize=(10,10))
corr_mat = sns.heatmap(df_final.corr(), vmin=-1, vmax=1, annot=True)
corr_mat.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# From the above correlation, it can be inferred that Generosity and Trust in Government has less impact to the individual happiness. GDP and Health programs in the country has most impact to the individual happiness.

# %% [markdown]
# #### Pair Plot:

# %%
sns.pairplot(df_final)

# %% [markdown]
# #### Relationship of Economy (GDP per Capita) and Happiness Score by Region

# %%
df_final['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 186
# Central and Eastern Europe         144
# Latin America and Caribbean        109
# Western Europe                     103
# Middle East and Northern Africa     96
# Southeastern Asia                   44
# Southern Asia                       35
# Eastern Asia                        28
# North America                       10
# Australia and New Zealand           10
# Name: Region, dtype: int64

# %% [markdown]
# **3.1 GDP per Capita w.r.t. Asia Region**

# %% [markdown]
# Interested in different GDP for the countries, we first find only the southern Asia region and then combine Southeastrn and Eastern together.

# %%
#only for Southern Asia

df_region_southasia = df_final[df_final['Region'] == 'Southern Asia']

# %%
fig = px.bar(data_frame=df_region_southasia,
            x = 'Year',
            y = 'Economy (GDP per Capita)',
            color = 'Country',
            opacity=0.5,
            template='plotly_dark', 
            title='Economy per Capita For Southern Asian Countries',
             
            barmode='group')
            
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="648cd2a2-ee41-403f-a3e4-35a1e5feea55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("648cd2a2-ee41-403f-a3e4-35a1e5feea55")) {                    Plotly.newPlot(                        "648cd2a2-ee41-403f-a3e4-35a1e5feea55",                        [{"alignmentgroup": "True", "hovertemplate": "Country=Bhutan<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "Bhutan", "marker": {"color": "#636efa", "opacity": 0.5}, "name": "Bhutan", "offsetgroup": "Bhutan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.77042, 0.8527, 0.885416388511658, 0.796, 0.813], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Pakistan<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "Pakistan", "marker": {"color": "#EF553B", "opacity": 0.5}, "name": "Pakistan", "offsetgroup": "Pakistan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.59543, 0.68816, 0.72688353061676, 0.652, 0.677], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Bangladesh<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "Bangladesh", "marker": {"color": "#00cc96", "opacity": 0.5}, "name": "Bangladesh", "offsetgroup": "Bangladesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.39753, 0.54177, 0.586682975292206, 0.532, 0.562], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=India<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "India", "marker": {"color": "#ab63fa", "opacity": 0.5}, "name": "India", "offsetgroup": "India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.64499, 0.74036, 0.792221248149872, 0.721, 0.755], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Nepal<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "Nepal", "marker": {"color": "#FFA15A", "opacity": 0.5}, "name": "Nepal", "offsetgroup": "Nepal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.35997, 0.44626, 0.479820191860199, 0.425, 0.446], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Sri Lanka<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "Sri Lanka", "marker": {"color": "#19d3f3", "opacity": 0.5}, "name": "Sri Lanka", "offsetgroup": "Sri Lanka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.83524, 0.97318, 1.00985014438629, 0.918, 0.949], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Afghanistan<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>", "legendgroup": "Afghanistan", "marker": {"color": "#FF6692", "opacity": 0.5}, "name": "Afghanistan", "offsetgroup": "Afghanistan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [0.31982, 0.38227, 0.401477217674255, 0.332, 0.35], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "Country"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb( ...

# %% [markdown]
# Top 5 Asian contries in each year with highest GDP.
# From the Graph we can see that Sri Lanka has the highest GDP for all 5 years.

# %% [markdown]
#  **Combining Southeastern and Eastern Regions from Asia**

# %%
df_region_asia = df_final[df_final['Region'].isin(['Southeastern Asia', 'Eastern Asia','Southern Asia'])]

df_region_asia.head()
# Out:
#     Year      Country             Region  Economy (GDP per Capita)   Family  \
# 23  2015    Singapore  Southeastern Asia                   1.52186  1.02000
# 33  2015     Thailand  Southeastern Asia                   0.96690  1.26504
# 37  2015       Taiwan       Eastern Asia                   1.29098  1.07617
# 45  2015        Japan       Eastern Asia                   1.27074  1.25712
# 46  2015  South Korea       Eastern Asia                   1.24461  0.95774
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 23                   1.02525  0.54252                        0.49210
# 33                   0.73850  0.55664                        0.03187
# 37                   0.87530  0.39740                        0.08129
# 45                   0.99111  0.49615                        0.18060
# 46                   0.96538  0.33208                        0.07857
#
#     Generosity  Happiness Score  Happiness Rank
# 23     0.31105            6.798              24
# 33     0.57630            6.455              34
# 37     0.25376            6.298              38
# 45     0.10705            5.987              46
# 46     0.18557            5.984              47

# %%
fig = px.bar(data_frame=df_region_asia,
            x = 'Country',
            y = 'Economy (GDP per Capita)',
            color = 'Country',
            barmode='group',
            orientation= 'v',
            
            title='Economy per Capita For Eastern,Southern Asia and Southern Eastern Asia Countries',
             
            animation_frame='Year', 
            range_y=[0,2],
             
            template='plotly_dark',
            text='Happiness Score'
            )
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside',
                 width = [0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4]) # thickness of the bar
fig.show()
# Out:
# <div>                            <div id="c2ef8d3d-3413-403d-9595-dcb9e73d6ec9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2ef8d3d-3413-403d-9595-dcb9e73d6ec9")) {                    Plotly.newPlot(                        "c2ef8d3d-3413-403d-9595-dcb9e73d6ec9",                        [{"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Singapore", "marker": {"color": "#636efa"}, "name": "Singapore", "offsetgroup": "Singapore", "orientation": "v", "showlegend": true, "text": [6.798], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "width": [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4], "x": ["Singapore"], "xaxis": "x", "y": [1.52186], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Thailand", "marker": {"color": "#EF553B"}, "name": "Thailand", "offsetgroup": "Thailand", "orientation": "v", "showlegend": true, "text": [6.455], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "width": [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4], "x": ["Thailand"], "xaxis": "x", "y": [0.9669], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Taiwan", "marker": {"color": "#00cc96"}, "name": "Taiwan", "offsetgroup": "Taiwan", "orientation": "v", "showlegend": true, "text": [6.298], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "width": [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4], "x": ["Taiwan"], "xaxis": "x", "y": [1.29098], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Japan", "marker": {"color": "#ab63fa"}, "name": "Japan", "offsetgroup": "Japan", "orientation": "v", "showlegend": true, "text": [5.987], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "width": [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4], "x": ["Japan"], "xaxis": "x", "y": [1.27074], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "South Korea", "marker": {"color": "#FFA15A"}, "name": "South Korea", "offsetgroup": "South Korea", "orientation": "v", "showlegend": true, "text": [5.984], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "width": [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4], "x": ["South Korea"], "xaxis": "x", "y": [1.24461], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Malaysia", "marker": {"color": "#19d3f3"}, "name": "Malaysia", "offsetgroup": "Malaysia", "orientation": "v", "showlegend": true, "text": [5.77], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "width": [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4], "x": ["Malaysia"], "xaxis": "x", "y": [1.12486], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=%{x}<br>Year=2015<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Hong Kong", "marker": {"color": "#FF6692"}, "name": "Hong Kong", "offsetgroup": "Hong Kong", "orientation": ...

# %% [markdown]
# Here we can see that even though happiness score is same for few countries but their GDP is quite different. So even though asian countries have highest GDP they do not have highest happiness score.

# %% [markdown]
# **3.2 GDP per Capita w.r.t. African Countries.**
#
# 1. Different GDP for the countries, we look for Countries in Africa and their GDP per Capita.

# %%
# Plot with Sub-Saharian-Africaan countries vs GDP

df_region_africa = df_final[df_final['Region'].isin(['Sub-Saharan Africa', 'Middle East and Northern Africa'])]

df_region_africa.head()
# Out:
#     Year               Country                           Region  \
# 10  2015                Israel  Middle East and Northern Africa
# 19  2015  United Arab Emirates  Middle East and Northern Africa
# 21  2015                  Oman  Middle East and Northern Africa
# 27  2015                 Qatar  Middle East and Northern Africa
# 34  2015          Saudi Arabia  Middle East and Northern Africa
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 10                   1.22857  1.22393                   0.91387  0.41319
# 19                   1.42727  1.12575                   0.80925  0.64157
# 21                   1.36011  1.08182                   0.76276  0.63274
# 27                   1.69042  1.07860                   0.79733  0.64040
# 34                   1.39541  1.08393                   0.72025  0.31048
#
#     Trust (Government Corruption)  Generosity  Happiness Score  Happiness Rank
# 10                        0.07785     0.33172            7.278              11
# 19                        0.38583     0.26428            6.901              20
# 21                        0.32524     0.21542            6.853              22
# 27                        0.52208     0.32573            6.611              28
# 34                        0.32524     0.13706            6.411              35

# %%
df_final.describe()
# Out:
#               Year  Economy (GDP per Capita)      Family  \
# count   765.000000                765.000000  765.000000
# mean   2016.968627                  0.920905    1.080035
# std       1.417563                  0.402757    0.326332
# min    2015.000000                  0.000000    0.000000
# 25%    2016.000000                  0.620000    0.869080
# 50%    2017.000000                  0.985000    1.123236
# 75%    2018.000000                  1.238000    1.330000
# max    2019.000000                  2.096000    1.644000
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                765.000000  765.000000                     765.000000
# mean                   0.616014    0.411172                       0.125866
# std                    0.244228    0.153349                       0.106449
# min                    0.000000    0.000000                       0.000000
# 25%                    0.449000    0.309410                       0.054000
# 50%                    0.649547    0.431660                       0.090810
# 75%                    0.808000    0.531311                       0.155353
# max                    1.141000    0.724000                       0.551910
#
#        Generosity  Happiness Score  Happiness Rank
# count  765.000000       765.000000      765.000000
# mean     0.218690         5.393793       78.206536
# std      0.123212         1.122498       45.127298
# min      0.000000         2.839000        1.000000
# 25%      0.129762         4.513000       39.000000
# 50%      0.201964         5.332000       78.000000
# 75%      0.279920         6.199000      117.000000
# max      0.838075         7.769000      158.000000

# %%
df_final[df_final['Generosity']==0]
# Out:
#      Year Country          Region  Economy (GDP per Capita)    Family  \
# 101  2015  Greece  Western Europe                  1.154060  0.929330
# 256  2016  Greece  Western Europe                  1.248860  0.754730
# 399  2017  Greece  Western Europe                  1.289487  1.239415
# 541  2018  Greece  Western Europe                  1.154000  1.202000
# 695  2019  Greece  Western Europe                  1.181000  1.156000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 101                  0.882130  0.076990                        0.01397
# 256                  0.800290  0.058220                        0.04127
# 399                  0.810199  0.095731                        0.04329
# 541                  0.879000  0.131000                        0.04400
# 695                  0.999000  0.067000                        0.03400
#
#      Generosity  Happiness Score  Happiness Rank
# 101         0.0            4.857             102
# 256         0.0            5.033              99
# 399         0.0            5.227              87
# 541         0.0            5.358              79
# 695         0.0            5.287              82

# %%
fig = px.bar(data_frame=df_region_africa,
            x = 'Year',
            y = 'Economy (GDP per Capita)',
            color = 'Country',
            barmode='group',
            orientation= 'v',
            template='plotly_dark', 
            text='Happiness Score',            
           
            labels={'Economy (GDP per Capita)':'Economy',
                    'Year':'Year'},           
            title='Economy per Capita For Sub - African Countries', 
            )



fig.show()
# Out:
# <div>                            <div id="6a590cb2-63e8-4957-8156-10872daf52c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a590cb2-63e8-4957-8156-10872daf52c3")) {                    Plotly.newPlot(                        "6a590cb2-63e8-4957-8156-10872daf52c3",                        [{"alignmentgroup": "True", "hovertemplate": "Country=Israel<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Israel", "marker": {"color": "#636efa"}, "name": "Israel", "offsetgroup": "Israel", "orientation": "v", "showlegend": true, "text": [7.278, 7.267, 7.21299982070923, 6.814, 7.139], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.22857, 1.33766, 1.37538242340088, 1.301, 1.276], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=United Arab Emirates<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "United Arab Emirates", "marker": {"color": "#EF553B"}, "name": "United Arab Emirates", "offsetgroup": "United Arab Emirates", "orientation": "v", "showlegend": true, "text": [6.901, 6.573, 6.64799976348877, 6.774, 6.825], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.42727, 1.57352, 1.62634336948395, 2.096, 1.503], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Oman<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Oman", "marker": {"color": "#00cc96"}, "name": "Oman", "offsetgroup": "Oman", "orientation": "v", "showlegend": true, "text": [6.853], "textposition": "auto", "type": "bar", "x": [2015], "xaxis": "x", "y": [1.36011], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Qatar<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Qatar", "marker": {"color": "#ab63fa"}, "name": "Qatar", "offsetgroup": "Qatar", "orientation": "v", "showlegend": true, "text": [6.611, 6.375, 6.375, 6.374, 6.374], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.69042, 1.82427, 1.87076568603516, 1.649, 1.684], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Saudi Arabia<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Saudi Arabia", "marker": {"color": "#FFA15A"}, "name": "Saudi Arabia", "offsetgroup": "Saudi Arabia", "orientation": "v", "showlegend": true, "text": [6.411, 6.379, 6.3439998626709, 6.371, 6.375], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.39541, 1.48953, 1.53062355518341, 1.379, 1.403], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Kuwait<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Kuwait", "marker": {"color": "#19d3f3"}, "name": "Kuwait", "offsetgroup": "Kuwait", "orientation": "v", "showlegend": true, "text": [6.295, 6.239, 6.10500001907349, 6.083, 6.021], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.55422, 1.61714, 1.63295245170593, 1.474, 1.5], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Bahrain<br>Year=%{x}<br>Economy=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Bahrain", "marker": {"color": "#FF6692"}, "name": "Bahrain", "offsetgroup": "Bahrain", "orientation": "v", "showlegend": true, "text": [5.96, 6.218, 6.08699989318848, 6.105, 6.199], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.32376, 1.44024, 1.48841226100922, 1.338, 1.362], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Libya<br>Year=%{x}<br>Econ ...

# %% [markdown]
# In year 2018 UAE has overtake Quatar in GDP. But in 2019 Quatar retained back its rank.
# From the above graph Africa dose not follow the same trend as Asia, as in Africa happiness score and GDP are highly correlated.

# %% [markdown]
# **3.3 Economy (GDP per Capita) w.r.t. European Countries.**

# %%
df_region_europe = df_final[df_final['Region'].isin(['Western Europe', 'Central and Eastern Europe'])]

# %%
fig = px.bar(data_frame=df_region_europe,
            x = 'Year',
            y = 'Economy (GDP per Capita)',
            color = 'Country',
            text='Happiness Score',            

            opacity=0.5,
            template='plotly_dark',
            title='Economy per Capita For Europian Countries',
             
            barmode='group')
            
fig.show()
# Out:
# <div>                            <div id="2e1fff9c-9d20-4b1c-947f-31cd14cc9d64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e1fff9c-9d20-4b1c-947f-31cd14cc9d64")) {                    Plotly.newPlot(                        "2e1fff9c-9d20-4b1c-947f-31cd14cc9d64",                        [{"alignmentgroup": "True", "hovertemplate": "Country=Switzerland<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "opacity": 0.5}, "name": "Switzerland", "offsetgroup": "Switzerland", "orientation": "v", "showlegend": true, "text": [7.587, 7.509, 7.49399995803833, 7.487, 7.48], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.39651, 1.52733, 1.56497955322266, 1.42, 1.452], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Iceland<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#EF553B", "opacity": 0.5}, "name": "Iceland", "offsetgroup": "Iceland", "orientation": "v", "showlegend": true, "text": [7.561, 7.501, 7.50400018692017, 7.495, 7.494], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.30232, 1.42666, 1.480633020401, 1.343, 1.38], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Denmark<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#00cc96", "opacity": 0.5}, "name": "Denmark", "offsetgroup": "Denmark", "orientation": "v", "showlegend": true, "text": [7.527, 7.526, 7.52199983596802, 7.555, 7.6], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.32548, 1.44178, 1.48238301277161, 1.351, 1.383], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Norway<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Norway", "marker": {"color": "#ab63fa", "opacity": 0.5}, "name": "Norway", "offsetgroup": "Norway", "orientation": "v", "showlegend": true, "text": [7.522, 7.498, 7.53700017929077, 7.594, 7.554], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.459, 1.57744, 1.61646318435669, 1.456, 1.488], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Finland<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#FFA15A", "opacity": 0.5}, "name": "Finland", "offsetgroup": "Finland", "orientation": "v", "showlegend": true, "text": [7.406, 7.413, 7.4689998626709, 7.632, 7.769], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.29025, 1.40598, 1.44357192516327, 1.305, 1.34], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Netherlands<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#19d3f3", "opacity": 0.5}, "name": "Netherlands", "offsetgroup": "Netherlands", "orientation": "v", "showlegend": true, "text": [7.378, 7.339, 7.3769998550415, 7.441, 7.488], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1.32944, 1.46468, 1.50394463539124, 1.361, 1.396], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Country=Sweden<br>Year=%{x}<br>Economy (GDP per Capita)=%{y}<br>Happiness Score=%{text}<extra></extra>", "legendgroup": "Sweden", "marker": {"color": "#FF6692", "opacity": 0.5}, "name": "Sweden", "offsetgroup": "Sweden", "orientation": "v", ...

# %% [markdown]
# Luxembourg has the highest GDP for all 5 years.
# Switzerland having the highest happiness score and having 3rd highest GDP score

# %% [markdown]
# #### 4. Heath (Life Expectancy) and Happiness Score by each Region and Country

# %% [markdown]
# From the correlation table the next highly influencial index for Happiness score is health of the country. Lets find out how health of the country has changed over years.

# %% [markdown]
# **4.1 Health (Life Expectancy) for Southern Asia Countries for different Years**

# %%
go.Figure(data=[go.Pie(labels=df_final.Region.value_counts().index, values=df_final.Region.value_counts().values)])
# Out:
# <div>                            <div id="ddf90cfc-35e5-48fe-9b6c-bc0efa8fae29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddf90cfc-35e5-48fe-9b6c-bc0efa8fae29")) {                    Plotly.newPlot(                        "ddf90cfc-35e5-48fe-9b6c-bc0efa8fae29",                        [{"labels": ["Sub-Saharan Africa", "Central and Eastern Europe", "Latin America and Caribbean", "Western Europe", "Middle East and Northern Africa", "Southeastern Asia", "Southern Asia", "Eastern Asia", "North America", "Australia and New Zealand"], "type": "pie", "values": [186, 144, 109, 103, 96, 44, 35, 28, 10, 10]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewi ...

# %%
 df_region_southasia.shape
# Out:
# (35, 11)

# %%
fig = px.scatter(df_region_southasia,
                x = 'Health (Life Expectancy)',
                y = 'Happiness Score',
                color = 'Country',
                
                facet_row = 'Year',
                labels ={"Happiness Score":"H Score"},
                template='plotly_dark',

                title = 'Health vs Happiness Score for South Asia'
                )

fig.show()
# Out:
# <div>                            <div id="ae937b24-997d-4dc4-9051-f85a67243dd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae937b24-997d-4dc4-9051-f85a67243dd0")) {                    Plotly.newPlot(                        "ae937b24-997d-4dc4-9051-f85a67243dd0",                        [{"hovertemplate": "Country=Bhutan<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Bhutan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Bhutan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.57407], "xaxis": "x5", "y": [5.253], "yaxis": "y5"}, {"hovertemplate": "Country=Bhutan<br>Year=2016<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Bhutan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Bhutan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.49759], "xaxis": "x4", "y": [5.196], "yaxis": "y4"}, {"hovertemplate": "Country=Bhutan<br>Year=2017<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Bhutan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Bhutan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.495879292488098], "xaxis": "x3", "y": [5.01100015640259], "yaxis": "y3"}, {"hovertemplate": "Country=Bhutan<br>Year=2018<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Bhutan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Bhutan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.527], "xaxis": "x2", "y": [5.082], "yaxis": "y2"}, {"hovertemplate": "Country=Bhutan<br>Year=2019<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Bhutan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Bhutan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.604], "xaxis": "x", "y": [5.082], "yaxis": "y"}, {"hovertemplate": "Country=Pakistan<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Pakistan", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.51466], "xaxis": "x5", "y": [5.194], "yaxis": "y5"}, {"hovertemplate": "Country=Pakistan<br>Year=2016<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Pakistan", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.40306], "xaxis": "x4", "y": [5.132], "yaxis": "y4"}, {"hovertemplate": "Country=Pakistan<br>Year=2017<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Pakistan", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.402047783136368], "xaxis": "x3", "y": [5.26900005340576], "yaxis": "y3"}, {"hovertemplate": "Country=Pakistan<br>Year=2018<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Pakistan", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.424], "xaxis": "x2", "y": [5.472], "yaxis": "y2"}, {"hovertemplate": "Country=Pakistan<br>Year=2019<br>Health (Life Expectancy)=%{x}<br>H Score=%{y}<extra></extra>", "legendgroup": "Pakistan", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": false, "type": ...

# %% [markdown]
# Every year Sri Lanka and Bangladesh have highest Health life expectancy.
# But their happiness score is ranging between 4 and 5.
#
# Although Bhutan has highest happiness score it has average Health life expectancy.

# %% [markdown]
# **4.2 Life Expectency vs Happiness for European Countries**

# %%
t= df_region_europe[df_region_europe['Region']=='Western Europe']
t.Country.unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Finland',
#        'Netherlands', 'Sweden', 'Austria', 'Luxembourg', 'Ireland',
#        'Belgium', 'United Kingdom', 'Germany', 'France', 'Spain', 'Malta',
#        'Italy', 'North Cyprus', 'Cyprus', 'Portugal', 'Greece'],
#       dtype=object)

# %%
fig = px.scatter(df_region_europe,
                x = 'Health (Life Expectancy)',
                y = 'Happiness Score',
                color = 'Country', 
                template='plotly_dark',
                facet_col = 'Year',
                facet_col_wrap = 5,
                labels ={"Health (Life Expectancy)":"Health"},
                title = 'Health vs Happiness Score for Europe, with Bubble size indication of GDP',
                )
fig.show()
# Out:
# <div>                            <div id="4bc129d3-022a-428e-bb43-bf9cddbf2460" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bc129d3-022a-428e-bb43-bf9cddbf2460")) {                    Plotly.newPlot(                        "4bc129d3-022a-428e-bb43-bf9cddbf2460",                        [{"hovertemplate": "Country=Switzerland<br>Year=2015<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.94143], "xaxis": "x", "y": [7.587], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Year=2016<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.86303], "xaxis": "x2", "y": [7.509], "yaxis": "y2"}, {"hovertemplate": "Country=Switzerland<br>Year=2017<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.858131289482117], "xaxis": "x3", "y": [7.49399995803833], "yaxis": "y3"}, {"hovertemplate": "Country=Switzerland<br>Year=2018<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.927], "xaxis": "x4", "y": [7.487], "yaxis": "y4"}, {"hovertemplate": "Country=Switzerland<br>Year=2019<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1.052], "xaxis": "x5", "y": [7.48], "yaxis": "y5"}, {"hovertemplate": "Country=Iceland<br>Year=2015<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.94784], "xaxis": "x", "y": [7.561], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Year=2016<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.86733], "xaxis": "x2", "y": [7.501], "yaxis": "y2"}, {"hovertemplate": "Country=Iceland<br>Year=2017<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.833552122116089], "xaxis": "x3", "y": [7.50400018692017], "yaxis": "y3"}, {"hovertemplate": "Country=Iceland<br>Year=2018<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.914], "xaxis": "x4", "y": [7.495], "yaxis": "y4"}, {"hovertemplate": "Country=Iceland<br>Year=2019<br>Health=%{x}<br>Happiness Score=%{y}<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1.026], "xaxis": "x5", "y ...

# %% [markdown]
# There is bigger difference in European Countries from Western Europe which has higher Happiness score than Central and Eastern countries having less happiness score.

# %%
df_region_europe1 = df_region_europe[df_region_europe['Country'].isin(['Switzerland', 
                                                                       'Norway','Finland','Netherlands',
                                                                      'Sweden', 'Austria'])]

# %%
fig = px.scatter(df_region_europe1,
                x = 'Health (Life Expectancy)',
                y = 'Happiness Score',
                color = 'Country',
                size = 'Economy (GDP per Capita)', 
                template='plotly_dark',
                facet_col = 'Year',
                facet_col_wrap = 5,
                labels ={"Health (Life Expectancy)":"Health"},
                title = 'Health vs Happiness Score for Western European Countries, with Bubble size indicating of GDP',
                )
fig.show()
# Out:
# <div>                            <div id="3c6fde33-56b0-482b-bcec-d0e7a1331265" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c6fde33-56b0-482b-bcec-d0e7a1331265")) {                    Plotly.newPlot(                        "3c6fde33-56b0-482b-bcec-d0e7a1331265",                        [{"hovertemplate": "Country=Switzerland<br>Year=2015<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "size": [1.39651], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.94143], "xaxis": "x", "y": [7.587], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Year=2016<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "size": [1.52733], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.86303], "xaxis": "x2", "y": [7.509], "yaxis": "y2"}, {"hovertemplate": "Country=Switzerland<br>Year=2017<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "size": [1.56497955322266], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.858131289482117], "xaxis": "x3", "y": [7.49399995803833], "yaxis": "y3"}, {"hovertemplate": "Country=Switzerland<br>Year=2018<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "size": [1.42], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.927], "xaxis": "x4", "y": [7.487], "yaxis": "y4"}, {"hovertemplate": "Country=Switzerland<br>Year=2019<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "size": [1.452], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1.052], "xaxis": "x5", "y": [7.48], "yaxis": "y5"}, {"hovertemplate": "Country=Norway<br>Year=2015<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Norway", "marker": {"color": "#EF553B", "size": [1.459], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Norway", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.88521], "xaxis": "x", "y": [7.522], "yaxis": "y"}, {"hovertemplate": "Country=Norway<br>Year=2016<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Norway", "marker": {"color": "#EF553B", "size": [1.57744], "sizemode": "area", "sizeref": 0.004041157960891725, "symbol": "circle"}, "mode": "markers", "name": "Norway", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.79579], "xaxis": "x2", "y": [7.498], "yaxis": "y2"}, {"hovertemplate": "Country=Norway<br>Year=2017<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Norway", "marker": {"color": "#EF553B", "size": [ ...

# %% [markdown]
# From the above graph, can see how Western European have increased their Health(Life Expectancy) over the years.
#
# Austria had a dip from year 2015 to 2017 since one of the factor Health(Life Expectancy) was dropping, as the countries Health improved the Happiness score also gained.
#
# Finland has most gain in Europe in Happiness score, as they constantly improved the countries health. Switzerland has better health score and GDP than Finland but lack in overall Happiness Score.
#
# Next, lets compare with Central and Eastern European Countries.

# %%
df_region_europe2 = df_final[df_final['Region']=='Central and Eastern Europe']

# %%
fig = px.scatter(df_region_europe2,
                x = 'Health (Life Expectancy)',
                y = 'Happiness Score',
                color = 'Country',
                size = 'Economy (GDP per Capita)', 
                template='plotly_dark',
                facet_col = 'Year',
                facet_col_wrap = 5,
                labels ={"Health (Life Expectancy)":"Health"},
                title = 'Health vs Happiness Score for Central and Eastern Europe, with Bubble size indicating of GDP',
                )
fig.show()
# Out:
# <div>                            <div id="27c5c796-f3bf-4bd6-9e6f-d3e100ab50ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27c5c796-f3bf-4bd6-9e6f-d3e100ab50ea")) {                    Plotly.newPlot(                        "27c5c796-f3bf-4bd6-9e6f-d3e100ab50ea",                        [{"hovertemplate": "Country=Czech Republic<br>Year=2015<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Czech Republic", "marker": {"color": "#636efa", "size": [1.17898], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.84483], "xaxis": "x", "y": [6.505], "yaxis": "y"}, {"hovertemplate": "Country=Czech Republic<br>Year=2016<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Czech Republic", "marker": {"color": "#636efa", "size": [1.30915], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.76376], "xaxis": "x2", "y": [6.596], "yaxis": "y2"}, {"hovertemplate": "Country=Czech Republic<br>Year=2017<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Czech Republic", "marker": {"color": "#636efa", "size": [1.35268235206604], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.754444003105164], "xaxis": "x3", "y": [6.60900020599365], "yaxis": "y3"}, {"hovertemplate": "Country=Czech Republic<br>Year=2018<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Czech Republic", "marker": {"color": "#636efa", "size": [1.233], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.854], "xaxis": "x4", "y": [6.711], "yaxis": "y4"}, {"hovertemplate": "Country=Czech Republic<br>Year=2019<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Czech Republic", "marker": {"color": "#636efa", "size": [1.269], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.92], "xaxis": "x5", "y": [6.852], "yaxis": "y5"}, {"hovertemplate": "Country=Uzbekistan<br>Year=2015<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Uzbekistan", "marker": {"color": "#EF553B", "size": [0.63244], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Uzbekistan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.59772], "xaxis": "x", "y": [6.003], "yaxis": "y"}, {"hovertemplate": "Country=Uzbekistan<br>Year=2016<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "legendgroup": "Uzbekistan", "marker": {"color": "#EF553B", "size": [0.73591], "sizemode": "area", "sizeref": 0.0033817058801651, "symbol": "circle"}, "mode": "markers", "name": "Uzbekistan", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.50163], "xaxis": "x2", "y": [5.987], "yaxis": "y2"}, {"hovertemplate": "Country=Uzbekistan<br>Year=2017<br>Health=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<extra></extra>", "le ...

# %% [markdown]
# Czech Republic has the highest happiness score, more that average health life expectancy and it is gradually increasing
#
# Slovenia has the highest health life expectance for all 5 years but it has above average GDP and happiness score.
#
# Although Tajikistan has the lowest GDP for all 5 years its Happiness score and Health life expectance has an upward trend.

# %% [markdown]
# **4.3 Life Expectency vs Happiness for North America Countries**

# %%
df_final['Happiness Score'].median()
# Out:
# 5.332

# %%
df_region_america = df_final[df_final['Region']=='North America']

# %%
fig = px.scatter(df_region_america,
                x = 'Health (Life Expectancy)',
                y = 'Happiness Score',
                color = 'Country',
                template='plotly_dark',
                text = 'Year',
                size = 'Economy (GDP per Capita)',
                title = 'Health vs Happiness Score for America, with Bubble size indication of GDP'
                )

fig.show()
# Out:
# <div>                            <div id="a4fa01f9-c5b2-492b-bbcb-b2ee10caa9df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4fa01f9-c5b2-492b-bbcb-b2ee10caa9df")) {                    Plotly.newPlot(                        "a4fa01f9-c5b2-492b-bbcb-b2ee10caa9df",                        [{"hovertemplate": "Country=Canada<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<br>Year=%{text}<extra></extra>", "legendgroup": "Canada", "marker": {"color": "#636efa", "size": [1.32629, 1.44015, 1.47920441627502, 1.33, 1.365], "sizemode": "area", "sizeref": 0.003865648210048675, "symbol": "circle"}, "mode": "markers+text", "name": "Canada", "orientation": "v", "showlegend": true, "text": [2015.0, 2016.0, 2017.0, 2018.0, 2019.0], "type": "scatter", "x": [0.90563, 0.8276, 0.83455765247345, 0.896, 1.039], "xaxis": "x", "y": [7.427, 7.404, 7.31599998474121, 7.328, 7.278], "yaxis": "y"}, {"hovertemplate": "Country=United States<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{y}<br>Economy (GDP per Capita)=%{marker.size}<br>Year=%{text}<extra></extra>", "legendgroup": "United States", "marker": {"color": "#EF553B", "size": [1.39451, 1.50796, 1.54625928401947, 1.398, 1.433], "sizemode": "area", "sizeref": 0.003865648210048675, "symbol": "circle"}, "mode": "markers+text", "name": "United States", "orientation": "v", "showlegend": true, "text": [2015.0, 2016.0, 2017.0, 2018.0, 2019.0], "type": "scatter", "x": [0.86179, 0.779, 0.77428662776947, 0.819, 0.874], "xaxis": "x", "y": [7.119, 7.104, 6.99300003051758, 6.886, 6.892], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "Country"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type":  ...

# %% [markdown]
# From scatterplot above, Canada has better Happiness Score than United States, Canada has better Life Expectancy than US. Understandably, Canada has free health care, but over the year Canada Happiness has got lower score.

# %% [markdown]
# **4.4 Life Expectency vs Happiness for Selected Countries and changes over the year in Life Expectancy vs Happiness.**

# %% [markdown]
# Handpicked countries from all region. Will try using animation over scatter plot.

# %%
df_custom_countries = df_final[df_final['Country'].isin(['Switzerland', 'Norway',
                               'Austria', 'New Zealand',  'India', 'Bhutan',  'Israel',
                                'Bangladesh', 'Mauritius', 'Nigeria', 'Zambia', 'Czech Republic', 
                                'Uzbekistan', 'Slovakia','Canada', 'United States', 
                                'Poland', 'Turkmenistan', 'Costa Rica', 'Mexico', 'Brazil',
                                'Israel', 'United Arab Emirates', 
                                'Qatar', 'Saudi Arabia', 'Singapore', 'Thailand', 
                                'Philippines', 'Malaysia', 
                                'South Korea', 'Japan',  'Sri Lanka'
                                 ])]

# %%
fig = px.scatter(df_custom_countries,
                x = 'Health (Life Expectancy)',
                y = 'Happiness Score',
                color = 'Country',
                size = 'Happiness Score', 
                template='plotly_dark',

                title = 'Health vs Happiness Score, with Bubble size indication of GDP',
                animation_frame = 'Year',
                range_x = [-0.05,1.3], # define the x and y limit so that graph is not outbound.
                range_y = [2,9]
                #category_orders={'Year': [2015,2016,2017,2018,2019]},
                )

fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000 #speed of change from one from to next frames.
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 500 #speed of change in graph.

fig.show()
# Out:
# <div>                            <div id="71ddb04a-3b37-4d0a-8d09-b7841afc80aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71ddb04a-3b37-4d0a-8d09-b7841afc80aa")) {                    Plotly.newPlot(                        "71ddb04a-3b37-4d0a-8d09-b7841afc80aa",                        [{"hovertemplate": "Country=Switzerland<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#636efa", "size": [7.587], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.94143], "xaxis": "x", "y": [7.587], "yaxis": "y"}, {"hovertemplate": "Country=Norway<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Norway", "marker": {"color": "#EF553B", "size": [7.522], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Norway", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.88521], "xaxis": "x", "y": [7.522], "yaxis": "y"}, {"hovertemplate": "Country=Canada<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Canada", "marker": {"color": "#00cc96", "size": [7.427], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Canada", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.90563], "xaxis": "x", "y": [7.427], "yaxis": "y"}, {"hovertemplate": "Country=New Zealand<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "New Zealand", "marker": {"color": "#ab63fa", "size": [7.286], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "New Zealand", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.90837], "xaxis": "x", "y": [7.286], "yaxis": "y"}, {"hovertemplate": "Country=Israel<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Israel", "marker": {"color": "#FFA15A", "size": [7.278], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Israel", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.91387], "xaxis": "x", "y": [7.278], "yaxis": "y"}, {"hovertemplate": "Country=Costa Rica<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Costa Rica", "marker": {"color": "#19d3f3", "size": [7.226], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Costa Rica", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.86027], "xaxis": "x", "y": [7.226], "yaxis": "y"}, {"hovertemplate": "Country=Austria<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Austria", "marker": {"color": "#FF6692", "size": [7.2], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Austria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.89042], "xaxis": "x", "y": [7.2], "yaxis": "y"}, {"hovertemplate": "Country=Mexico<br>Year=2015<br>Health (Life Expectancy)=%{x}<br>Happiness Score=%{marker.size}<extra></extra>", "legendgroup": "Mexico", "marker": {"color": "#B6E880", "size": [7.187], "sizemode": "area", "sizeref": 0.018985000000000002, "symbol": "circle"}, "mode": "markers", "name": "Mexico", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.81444], "xaxis" ...

# %% [markdown]
# After selecting US, Canada, Austria and Norway for year 2015, they clustered together closely. By year 2017, they get declustered. US by year 2019 not only falls back in Health Life Expectancy but also gets lower score in Happiness Index. Where other three country have similiar Happiness Index and Health (Life Expectancy) by year 2019.
#
# After selecting Sri Lanka, Bangladesh , Bhutan and India their happiness score ranges form 3-5.5 for all 5 years, in 2016 and 2017 all 4 countries decreased a little. But after 2018 the incrased gradually.

# %% [markdown]
# #### Importance of Family Support in Happiness Index

# %% [markdown]
# Another important index for the dataset is Family Support. We will compare with various region and country to check its importance.

# %% [markdown]
# **5.1 Effect of Family Support on Happiness Index for countries.**

# %% [markdown]
# We look into southern Asia region.

# %%
df_region_southasia_2019 =  df_region_southasia[df_region_southasia['Year'] == 2019]
df_region_southasia_2019
# Out:
#      Year      Country         Region  Economy (GDP per Capita)  Family  \
# 680  2019     Pakistan  Southern Asia                     0.677   0.886
# 707  2019       Bhutan  Southern Asia                     0.813   1.321
# 712  2019        Nepal  Southern Asia                     0.446   1.226
# 734  2019   Bangladesh  Southern Asia                     0.562   0.928
# 739  2019    Sri Lanka  Southern Asia                     0.949   1.265
# 749  2019        India  Southern Asia                     0.755   0.765
# 763  2019  Afghanistan  Southern Asia                     0.350   0.517
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 680                     0.535    0.313                          0.098
# 707                     0.604    0.457                          0.167
# 712                     0.677    0.439                          0.089
# 734                     0.723    0.527                          0.143
# 739                     0.831    0.470                          0.047
# 749                     0.588    0.498                          0.085
# 763                     0.361    0.000                          0.025
#
#      Generosity  Happiness Score  Happiness Rank
# 680       0.220            5.653              67
# 707       0.370            5.082              95
# 712       0.285            4.913             100
# 734       0.166            4.456             125
# 739       0.244            4.366             130
# 749       0.200            4.015             140
# 763       0.158            3.203             154

# %%
df_region_southasia_2019.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).reset_index()
# Out:
#        Country  Happiness Score
# 0     Pakistan            5.653
# 1       Bhutan            5.082
# 2        Nepal            4.913
# 3   Bangladesh            4.456
# 4    Sri Lanka            4.366
# 5        India            4.015
# 6  Afghanistan            3.203

# %%
fig = px.pie(data_frame=df_region_southasia_2019,
             values='Family',
             names='Country',
             color='Country', 
            hover_name='Happiness Score',                        
             title='2019 Family Support Index for Southasia Country',
             template='plotly_dark',
             width=800,                          
             height=600,                         
             hole=0.5,                          
            )

fig.update_traces(textposition='inside', textinfo='percent+label')

fig.show()
# Out:
# <div>                            <div id="3c36d740-ff8c-49a2-8b51-cb9bb0fa2722" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c36d740-ff8c-49a2-8b51-cb9bb0fa2722")) {                    Plotly.newPlot(                        "3c36d740-ff8c-49a2-8b51-cb9bb0fa2722",                        [{"customdata": [["Pakistan"], ["Bhutan"], ["Nepal"], ["Bangladesh"], ["Sri Lanka"], ["India"], ["Afghanistan"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hovertemplate": "<b>%{hovertext}</b><br><br>Country=%{customdata[0]}<br>Family=%{value}<extra></extra>", "hovertext": [5.653, 5.082, 4.913, 4.456, 4.366, 4.015, 3.203], "labels": ["Pakistan", "Bhutan", "Nepal", "Bangladesh", "Sri Lanka", "India", "Afghanistan"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692"]}, "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [0.886, 1.321, 1.226, 0.928, 1.265, 0.765, 0.517]}],                        {"height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444 ...

# %% [markdown]
# From the above piechart, can see for year 2019, Bhutan has higher percent in pie for Family Support Index. Bhutan is the second happiest country for year 2019.

# %% [markdown]
# **5.2 Comparing Family Support with Happiness Index for African Countries.**

# %% [markdown]
# For next pie chart we shall use African Region

# %%
df_region_africa_2019 =  df_region_africa[df_region_africa['Year'] == 2019]

# %%
df_region_africa_2019.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).reset_index()
# Out:
#                      Country  Happiness Score
# 0                     Israel            7.139
# 1       United Arab Emirates            6.825
# 2               Saudi Arabia            6.375
# 3                      Qatar            6.374
# 4                    Bahrain            6.199
# 5                     Kuwait            6.021
# 6                  Mauritius            5.888
# 7                      Libya            5.525
# 8                     Turkey            5.373
# 9                    Nigeria            5.265
# 10                   Algeria            5.211
# 11                   Morocco            5.208
# 12                   Lebanon            5.197
# 13                  Cameroon            5.044
# 14                     Ghana            4.996
# 15               Ivory Coast            4.944
# 16                    Jordan            4.906
# 17                     Benin            4.883
# 18       Congo (Brazzaville)            4.812
# 19                     Gabon            4.799
# 20              South Africa            4.722
# 21   Palestinian Territories            4.696
# 22                   Senegal            4.681
# 23                     Niger            4.628
# 24              Burkina Faso            4.587
# 25                      Iran            4.548
# 26                    Guinea            4.534
# 27                     Kenya            4.509
# 28                Mauritania            4.490
# 29                Mozambique            4.466
# 30                   Tunisia            4.461
# 31                      Iraq            4.437
# 32          Congo (Kinshasa)            4.418
# 33                      Mali            4.390
# 34              Sierra Leone            4.374
# 35                      Chad            4.350
# 36                  Ethiopia            4.286
# 37                 Swaziland            4.212
# 38                    Uganda            4.189
# 39                     Egypt            4.166
# 40                    Zambia            4.107
# 41                      Togo            4.085
# 42                   Liberia            3.975
# 43                   Comoros            3.973
# 44                Madagascar            3.933
# 45                   Lesotho            3.802
# 46                   Burundi            3.775
# 47                  Zimbabwe            3.663
# 48                  Botswana            3.488
# 49                     Syria            3.462
# 50                    Malawi            3.410
# 51                     Yemen            3.380
# 52                    Rwanda            3.334
# 53                  Tanzania            3.231
# 54  Central African Republic            3.083

# %%
fig = px.pie(data_frame=df_region_africa_2019,
             values='Family',
             names='Country',
             color='Country',                           
             hover_name='Happiness Score',              
             title='2019 Family Support Index for Sub-Sahara African Countries',     
              template='plotly_dark',            
             width=800,                       
             height=600                         
                                        
            )

fig.show()
# Out:
# <div>                            <div id="52f99814-599d-421c-967b-6f0fd546e003" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52f99814-599d-421c-967b-6f0fd546e003")) {                    Plotly.newPlot(                        "52f99814-599d-421c-967b-6f0fd546e003",                        [{"customdata": [["Israel"], ["United Arab Emirates"], ["Saudi Arabia"], ["Qatar"], ["Bahrain"], ["Kuwait"], ["Mauritius"], ["Libya"], ["Turkey"], ["Nigeria"], ["Algeria"], ["Morocco"], ["Lebanon"], ["Cameroon"], ["Ghana"], ["Ivory Coast"], ["Jordan"], ["Benin"], ["Congo (Brazzaville)"], ["Gabon"], ["South Africa"], ["Palestinian Territories"], ["Senegal"], ["Niger"], ["Burkina Faso"], ["Iran"], ["Guinea"], ["Kenya"], ["Mauritania"], ["Mozambique"], ["Tunisia"], ["Iraq"], ["Congo (Kinshasa)"], ["Mali"], ["Sierra Leone"], ["Chad"], ["Ethiopia"], ["Swaziland"], ["Uganda"], ["Egypt"], ["Zambia"], ["Togo"], ["Liberia"], ["Comoros"], ["Madagascar"], ["Lesotho"], ["Burundi"], ["Zimbabwe"], ["Botswana"], ["Syria"], ["Malawi"], ["Yemen"], ["Rwanda"], ["Tanzania"], ["Central African Republic"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country=%{customdata[0]}<br>Family=%{value}<extra></extra>", "hovertext": [7.139, 6.825, 6.375, 6.374, 6.199, 6.021, 5.888, 5.525, 5.373, 5.265, 5.211, 5.208, 5.197, 5.044, 4.996, 4.944, 4.906, 4.883, 4.812, 4.799, 4.722, 4.696, 4.681, 4.628, 4.587, 4.548, 4.534, 4.509, 4.49, 4.466, 4.461, 4.437, 4.418, 4.39, 4.374, 4.35, 4.286, 4.212, 4.189, 4.166, 4.107, 4.085, 3.975, 3.973, 3.933, 3.802, 3.775, 3.663, 3.488, 3.462, 3.41, 3.38, 3.334, 3.231, 3.083], "labels": ["Israel", "United Arab Emirates", "Saudi Arabia", "Qatar", "Bahrain", "Kuwait", "Mauritius", "Libya", "Turkey", "Nigeria", "Algeria", "Morocco", "Lebanon", "Cameroon", "Ghana", "Ivory Coast", "Jordan", "Benin", "Congo (Brazzaville)", "Gabon", "South Africa", "Palestinian Territories", "Senegal", "Niger", "Burkina Faso", "Iran", "Guinea", "Kenya", "Mauritania", "Mozambique", "Tunisia", "Iraq", "Congo (Kinshasa)", "Mali", "Sierra Leone", "Chad", "Ethiopia", "Swaziland", "Uganda", "Egypt", "Zambia", "Togo", "Liberia", "Comoros", "Madagascar", "Lesotho", "Burundi", "Zimbabwe", "Botswana", "Syria", "Malawi", "Yemen", "Rwanda", "Tanzania", "Central African Republic"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3", "#FF6692", "#B6E880", "#FF97FF", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A"]}, "name": "", "showlegend": true, "type": "pie", "values": [1.455, 1.31, 1.357, 1.313, 1.368, 1.319, 1.402, 1.303, 1.36, 1.111, 1.16, 0.782, 1.224, 0.91, 0.868, 0.808, 1.225, 0.437, 0.799, 1.183, 1.351, 1.247, 1.134, 0.774, 1.056, 0.842, 0.829, 0.983, 1.167, 0.986, 1.0, 0.98, 1.125, 1.105, 0.841, 0.766, 1.033, 1.149, 1.069, 1.039, 1.058, 0.572, 0.922, 0.757, 0.916, 1.169, 0.447, 1.114, 1.145, 0.378, 0.56, 1.163, 0.711, 0.885, 0.0]}],                        {"height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{" ...

# %% [markdown]
# From the piechart above, Israel has highest percent for Family Support Index, and also has most Happiness Index in the region.

# %% [markdown]
# **5.3 Combine North America, Australia and New Zealand for Fmaily Index.**

# %% [markdown]
# For next pie chart we shall use North America, Australia and New Zealand Region

# %%
df_region_comb = df_final[df_final['Region'].isin(['North America', 'Australia and New Zealand'])]

# %%
df_region_comb.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).reset_index()
# Out:
#          Country  Happiness Score
# 0         Canada            7.427
# 1    New Zealand            7.334
# 2      Australia            7.313
# 3  United States            7.119

# %%
fig = px.pie(data_frame=df_region_comb,
             values='Family',
             names='Country',
             color='Country',
                                                             
             title='Family Index for America, Australia and New Zealand Countries for Years 2015 - 2019',     
             template='plotly_dark',            
             width=800,                          
             height=600,                         
             hole=0.5,                           
            )
fig.update_traces(textposition='inside', textinfo='percent+label'),


fig.show()
# Out:
# <div>                            <div id="59c86e62-ce33-4130-abd7-9be0d7e236f6" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59c86e62-ce33-4130-abd7-9be0d7e236f6")) {                    Plotly.newPlot(                        "59c86e62-ce33-4130-abd7-9be0d7e236f6",                        [{"customdata": [["Canada"], ["New Zealand"], ["Australia"], ["United States"], ["Canada"], ["New Zealand"], ["Australia"], ["United States"], ["Canada"], ["New Zealand"], ["Australia"], ["United States"], ["Canada"], ["New Zealand"], ["Australia"], ["United States"], ["New Zealand"], ["Canada"], ["Australia"], ["United States"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hovertemplate": "Country=%{customdata[0]}<br>Family=%{value}<extra></extra>", "labels": ["Canada", "New Zealand", "Australia", "United States", "Canada", "New Zealand", "Australia", "United States", "Canada", "New Zealand", "Australia", "United States", "Canada", "New Zealand", "Australia", "United States", "New Zealand", "Canada", "Australia", "United States"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#636efa", "#EF553B", "#00cc96", "#ab63fa", "#EF553B", "#636efa", "#00cc96", "#ab63fa"]}, "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [1.32261, 1.31967, 1.30923, 1.24711, 1.0961, 1.17278, 1.10476, 1.04782, 1.48134899139404, 1.54819512367249, 1.51004195213318, 1.41992056369781, 1.532, 1.601, 1.573, 1.471, 1.557, 1.505, 1.548, 1.457]}],                        {"height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "h ...

# %% [markdown]
# Of the four countries above, US has least Family Support Index, so is its Happiness Score lower than the other countries.

# %% [markdown]
# **5.4 Effect of Family Support for countries.**

# %% [markdown]
# We look into Eastern Asia region

# %%
df_region_eastasia = df_final[df_final['Region'] == 'Eastern Asia']
df_region_eastasia_2019 = df_region_eastasia[df_region_eastasia['Year'] == 2019]
df_region_eastasia_2019
# Out:
#      Year      Country        Region  Economy (GDP per Capita)  Family  \
# 640  2019       Taiwan  Eastern Asia                     1.368   1.430
# 668  2019  South Korea  Eastern Asia                     1.301   1.219
# 672  2019        Japan  Eastern Asia                     1.327   1.419
# 689  2019    Hong Kong  Eastern Asia                     1.438   1.277
# 696  2019     Mongolia  Eastern Asia                     0.948   1.531
# 705  2019        China  Eastern Asia                     1.029   1.125
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 640                     0.914    0.351                          0.097
# 668                     1.036    0.159                          0.056
# 672                     1.088    0.445                          0.140
# 689                     1.122    0.440                          0.287
# 696                     0.667    0.317                          0.038
# 705                     0.893    0.521                          0.100
#
#      Generosity  Happiness Score  Happiness Rank
# 640       0.242            6.446              25
# 668       0.175            5.895              54
# 672       0.069            5.886              58
# 689       0.258            5.430              76
# 696       0.235            5.285              83
# 705       0.058            5.191              93

# %%
fig = px.pie(data_frame=df_region_eastasia_2019,
             values='Family',
             names='Country',
             color='Country',                      
             hover_name='Happiness Score',             
             template='plotly_dark',   
             title='2019 Family Support Index for East Asian Countries wiht Happiness Score.',     
                                                      
             width=800,                          
             height=600,                         
             hole=0.5,                           
            )

fig.update_traces(textposition='outside', textinfo='percent+label')



fig.show()
# Out:
# <div>                            <div id="67ada7bb-d98b-4513-b1ed-006cbf35fce8" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67ada7bb-d98b-4513-b1ed-006cbf35fce8")) {                    Plotly.newPlot(                        "67ada7bb-d98b-4513-b1ed-006cbf35fce8",                        [{"customdata": [["Taiwan"], ["South Korea"], ["Japan"], ["Hong Kong"], ["Mongolia"], ["China"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hovertemplate": "<b>%{hovertext}</b><br><br>Country=%{customdata[0]}<br>Family=%{value}<extra></extra>", "hovertext": [6.446, 5.895, 5.886, 5.43, 5.285, 5.191], "labels": ["Taiwan", "South Korea", "Japan", "Hong Kong", "Mongolia", "China"], "legendgroup": "", "marker": {"colors": ["#636efa", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#19d3f3"]}, "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "outside", "type": "pie", "values": [1.43, 1.219, 1.419, 1.277, 1.531, 1.125]}],                        {"height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"],  ...

# %% [markdown]
# From the above pie chart, we can find that China has least Family Support Index whereas Taiwan has better Family support, so is the rank of Taiwan on overall East Asian countries.

# %% [markdown]
# # Splitting Data

# %%
df_final.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Happiness Score', 'Happiness Rank'],
#       dtype='object')

# %%
df = df_final
df.head()
# Out:
#    Year      Country          Region  Economy (GDP per Capita)   Family  \
# 0  2015  Switzerland  Western Europe                   1.39651  1.34951
# 1  2015      Iceland  Western Europe                   1.30232  1.40223
# 2  2015      Denmark  Western Europe                   1.32548  1.36058
# 3  2015       Norway  Western Europe                   1.45900  1.33095
# 4  2015       Canada   North America                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Happiness Score  Happiness Rank
# 0     0.29678            7.587               1
# 1     0.43630            7.561               2
# 2     0.34139            7.527               3
# 3     0.34699            7.522               4
# 4     0.45811            7.427               5

# %%
# for each column heading we replace " " with "_" and conver the heading in lower case
cleancolumn = []
for i in range(len(df.columns)):
    cleancolumn.append(df.columns[i].replace(' ','_').lower())
df.columns = cleancolumn

# %%
df.columns
# Out:
# Index(['year', 'country', 'region', 'economy_(gdp_per_capita)', 'family',
#        'health_(life_expectancy)', 'freedom', 'trust_(government_corruption)',
#        'generosity', 'happiness_score', 'happiness_rank'],
#       dtype='object')

# %%
df.region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
# performing label encoding on 'region' columns
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['region'] = labelencoder.fit_transform(df['region'])
df.head(10)
# Out:
#    year      country  region  economy_(gdp_per_capita)   family  \
# 0  2015  Switzerland       9                   1.39651  1.34951
# 1  2015      Iceland       9                   1.30232  1.40223
# 2  2015      Denmark       9                   1.32548  1.36058
# 3  2015       Norway       9                   1.45900  1.33095
# 4  2015       Canada       5                   1.32629  1.32261
# 5  2015      Finland       9                   1.29025  1.31826
# 6  2015  Netherlands       9                   1.32944  1.28017
# 7  2015       Sweden       9                   1.33171  1.28907
# 8  2015  New Zealand       0                   1.25018  1.31967
# 9  2015    Australia       0                   1.33358  1.30923
#
#    health_(life_expectancy)  freedom  trust_(government_corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    generosity  happiness_score  happiness_rank
# 0     0.29678            7.587               1
# 1     0.43630            7.561               2
# 2     0.34139            7.527               3
# 3     0.34699            7.522               4
# 4     0.45811            7.427               5
# 5     0.23351            7.406               6
# 6     0.47610            7.378               7
# 7     0.36262            7.364               8
# 8     0.47501            7.286               9
# 9     0.43562            7.284              10

# %%
df[df.columns[:]].corr()['happiness_score'][:]
# Out:
# year                             0.016713
# region                          -0.166142
# economy_(gdp_per_capita)         0.787090
# family                           0.644413
# health_(life_expectancy)         0.739322
# freedom                          0.552105
# trust_(government_corruption)    0.407131
# generosity                       0.139523
# happiness_score                  1.000000
# happiness_rank                  -0.992525
# Name: happiness_score, dtype: float64

# %%
happyall_score_top10 = df.groupby(['year'])['year','country','happiness_score']
happyall_score_top10.columns = ['Year','country','happiness_score']
happyall_score_top10.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#      year      country  happiness_score
# 0    2015  Switzerland            7.587
# 1    2015      Iceland            7.561
# 2    2015      Denmark            7.527
# 3    2015       Norway            7.522
# 4    2015       Canada            7.427
# 158  2016      Denmark            7.526
# 159  2016  Switzerland            7.509
# 160  2016      Iceland            7.501
# 161  2016       Norway            7.498
# 162  2016      Finland            7.413
# 315  2017       Norway            7.537
# 316  2017      Denmark            7.522
# 317  2017      Iceland            7.504
# 318  2017  Switzerland            7.494
# 319  2017      Finland            7.469
# 465  2018      Finland            7.632
# 466  2018       Norway            7.594
# 467  2018      Denmark            7.555
# 468  2018      Iceland            7.495
# 469  2018  Switzerland            7.487
# 616  2019      Finland            7.769
# 617  2019      Denmark            7.600
# 618  2019       Norway            7.554
# 619  2019      Iceland            7.494
# 620  2019  Netherlands            7.488

# %%
X = df[['economy_(gdp_per_capita)', 'family','region',
       'health_(life_expectancy)', 'freedom', 'trust_(government_corruption)',
       'generosity']]
X.head()
# Out:
#    economy_(gdp_per_capita)   family  region  health_(life_expectancy)  \
# 0                   1.39651  1.34951       9                   0.94143
# 1                   1.30232  1.40223       9                   0.94784
# 2                   1.32548  1.36058       9                   0.87464
# 3                   1.45900  1.33095       9                   0.88521
# 4                   1.32629  1.32261       5                   0.90563
#
#    freedom  trust_(government_corruption)  generosity
# 0  0.66557                        0.41978     0.29678
# 1  0.62877                        0.14145     0.43630
# 2  0.64938                        0.48357     0.34139
# 3  0.66973                        0.36503     0.34699
# 4  0.63297                        0.32957     0.45811

# %%
y= df.happiness_score
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: happiness_score, dtype: float64

# %%
# load the libraries required for data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
! pip install xgboost
import xgboost as xgb
# Out:
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.7/site-packages (1.4.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.5.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.19.5)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=10)
X_train.shape, X_test.shape, y_train.shape ,y_test.shape
# Out:
# ((535, 7), (230, 7), (535,), (230,))

# %% [markdown]
# # Model

# %% [markdown]
# ### Linear Regression

# %%
model_lr = LinearRegression()

# %%
model_lr.fit(X_train,y_train)
model_lr.score(X_train,y_train)
# Out:
# 0.7615489766065676

# %%
model_lr.coef_  #value of m i.e slope
# Out:
# array([ 1.11272235,  0.7140024 , -0.0070152 ,  0.91335568,  1.42667085,
#         1.08762289,  0.49080151])

# %%
model_lr.intercept_  #Value of C
# Out:
# 2.244853499166402

# %%
y_pred_test = model_lr.predict(X_test)
y_pred_test[:5]
# Out:
# array([4.03461223, 3.94041031, 5.49524764, 5.05741536, 6.75032065])

# %%
rmse_test_lr = np.sqrt(mean_squared_error(y_test, y_pred_test))  #root mean squared error
print(model_lr.score(X_test,y_test))    
SSE = np.sum((y_pred_test-y_test)**2)  #sum of square error
SST = np.sum((y_test-np.mean(y_train))**2)  #sum of square total
r2_test_lr = 1 - SSE/SST #statistical measure of how close the data are to the fitted regression line
print("Test RMSE LR : ", rmse_test_lr)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 LR: ", r2_test_lr)
# Out:
# 0.7610144782394568
# Test RMSE LR :  0.5625757163871621
# Test SSE :  72.79303043376157
# Test SST :  304.65279984436444
# Test R2 LR:  0.7610623290810103

# %% [markdown]
# Ploting bestfit line on highly coorelated feature vs Happiness score

# %%
model_lr1 = LinearRegression()
model_lr1.fit(X_train[['economy_(gdp_per_capita)']],y_train)
print(model_lr1.score(X_train[['economy_(gdp_per_capita)']],y_train))
print(model_lr1.coef_)
print(model_lr1.intercept_)
y_pred_train1 = model_lr1.predict(df[['economy_(gdp_per_capita)']])
# Out:
# 0.6178164286230874
# [2.17661191]
# 3.3801025344570745

# %%
plt.scatter(df[['economy_(gdp_per_capita)']],df['happiness_score']) #bestfit line  
plt.plot(df[['economy_(gdp_per_capita)']],y_pred_train,'r')
plt.axis([-1,2.5,2,7])
plt.xlabel('gdp_per_capita')
plt.ylabel('score')
plt.title('Linear Regression on GDP ~ Happiness Score')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-c49de32c86da> in <module>
#       1 plt.scatter(df[['economy_(gdp_per_capita)']],df['happiness_score']) #bestfit line
# ----> 2 plt.plot(df[['economy_(gdp_per_capita)']],y_pred_train,'r')
#       3 plt.axis([-1,2.5,2,7])
#       4 plt.xlabel('gdp_per_capita')
#       5 plt.ylabel('score')
#
# NameError: name 'y_pred_train' is not defined

# %% [markdown]
# #### RFE

# %%
from sklearn.feature_selection import RFE  #recursive feature elimination

# %%
model_rfe = LinearRegression()

# %%
rfe = RFE(estimator=model_rfe, step=1,verbose=2)
rfe.fit(X_train, y_train)
rfe.ranking_
# Out:
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# array([1, 3, 5, 1, 1, 2, 4])

# %%
selected_rfe_features = pd.DataFrame({'Feature':list(X_train.columns),
                                      'Ranking':rfe.ranking_})
selected_rfe_features.sort_values(by='Ranking')
# Out:
#                          Feature  Ranking
# 0       economy_(gdp_per_capita)        1
# 3       health_(life_expectancy)        1
# 4                        freedom        1
# 5  trust_(government_corruption)        2
# 1                         family        3
# 6                     generosity        4
# 2                         region        5

# %%
X_train_rfe = rfe.transform(X_train) 
X_train_rfe.shape
# Out:
# (535, 3)

# %%
model_rfe.fit(X_train_rfe,y_train)
model_rfe.score(X_train_rfe,y_train)
# Out:
# 0.7304564074131231

# %%
y_pred_rfe = model_rfe.predict(X_test[['economy_(gdp_per_capita)','health_(life_expectancy)','freedom']])

# %%
rmse_test_rfe = np.sqrt(mean_squared_error(y_test, y_pred_rfe))
print(model_rfe.score(X_test[['economy_(gdp_per_capita)','health_(life_expectancy)','freedom']],y_test))   
SSE = np.sum((y_pred_rfe-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_rfe = 1 - SSE/SST
print("Test RMSE LR : ", rmse_test_rfe)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 LR: ", r2_test_rfe)
# Out:
# 0.7472115721180412
# Test RMSE LR :  0.5785938068519235
# Test SSE :  76.99728246530222
# Test SST :  304.65279984436444
# Test R2 LR:  0.7472621866444779

# %% [markdown]
# ### Decision Tree

# %%
max_depths = np.linspace(1, 15, 15, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
   dt = DecisionTreeRegressor(max_depth=max_depth)
   dt.fit(X_train, y_train)
   train_pred = dt.predict(X_train)
   rmse_train_dt = np.sqrt(mean_squared_error(y_train, train_pred))
   SSE = np.sum((train_pred-y_train)**2)
   SST = np.sum((y_train-np.mean(y_train))**2)
   r2_train_dt = 1 - SSE/SST
   train_results.append(r2_train_dt)

   test_pred = dt.predict(X_test)
   rmse_test_dt = np.sqrt(mean_squared_error(y_test, test_pred))
   SSE = np.sum((test_pred -y_test)**2)
   SST = np.sum((y_test-np.mean(y_test))**2)
   r2_test_dt = 1 - SSE/SST
   test_results.append(r2_test_dt)
   

line1 = plt.plot(max_depths, train_results, 'b')
line2 = plt.plot(max_depths, test_results, 'r')
plt.ylabel('R2 score')
plt.xlabel('Tree depth')
plt.title('Depth vs R2 Score')
plt.show()

# %% [markdown]
# Max_depth of 4 gives minimum difference between train and test.
#
# If Max_depth > 4 model will overfit according to graph as difference between test and train increases
#
# If Max_depth < 4 model is giving less accuracy on train

# %%
model_dt = DecisionTreeRegressor(max_depth=4)

# %%
model_dt.fit(X_train,y_train)
model_dt.score(X_train,y_train)
# Out:
# 0.8083850384524076

# %%
y_pred_test_ds = model_dt.predict(X_test)
y_pred_test_ds[:5]
rmse_test_dt = np.sqrt(mean_squared_error(y_test, y_pred_test_ds))
print(model_dt.score(X_test,y_test))   
SSE = np.sum((y_pred_test_ds-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_dt = 1 - SSE/SST
print("Test RMSE DT : ", rmse_test_dt)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 DT: ", r2_test_dt)
# Out:
# 0.7630285613178324
# Test RMSE DT :  0.5602001088198035
# Test SSE :  72.17955724199552
# Test SST :  304.65279984436444
# Test R2 DT:  0.7630760088898926

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image
export_graphviz(model_dt,out_file='Regtree.dot',feature_names=X_train.columns)
! dot -Tpng Regtree.dot -o Regtree.png
Image("Regtree.png")

# %% [markdown]
# ### Ensemble Method

# %% [markdown]
# #### Bagging

# %%
model_bag = BaggingRegressor(base_estimator=DecisionTreeRegressor(max_depth=4),n_estimators=100,oob_score=True,random_state=410,verbose=2)

# %%
model_bag.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Building estimator 1 of 100 for this parallel run (total 100)...
# Building estimator 2 of 100 for this parallel run (total 100)...
# Building estimator 3 of 100 for this parallel run (total 100)...
# Building estimator 4 of 100 for this parallel run (total 100)...
# Building estimator 5 of 100 for this parallel run (total 100)...
# Building estimator 6 of 100 for this parallel run (total 100)...
# Building estimator 7 of 100 for this parallel run (total 100)...
# Building estimator 8 of 100 for this parallel run (total 100)...
# Building estimator 9 of 100 for this parallel run (total 100)...
# Building estimator 10 of 100 for this parallel run (total 100)...
# Building estimator 11 of 100 for this parallel run (total 100)...
# Building estimator 12 of 100 for this parallel run (total 100)...
# Building estimator 13 of 100 for this parallel run (total 100)...
# Building estimator 14 of 100 for this parallel run (total 100)...
# Building estimator 15 of 100 for this parallel run (total 100)...
# Building estimator 16 of 100 for this parallel run (total 100)...
# Building estimator 17 of 100 for this parallel run (total 100)...
# Building estimator 18 of 100 for this parallel run (total 100)...
# Building estimator 19 of 100 for this parallel run (total 100)...
# Building estimator 20 of 100 for this parallel run (total 100)...
# Building estimator 21 of 100 for this parallel run (total 100)...
# Building estimator 22 of 100 for this parallel run (total 100)...
# Building estimator 23 of 100 for this parallel run (total 100)...
# Building estimator 24 of 100 for this parallel run (total 100)...
# Building estimator 25 of 100 for this parallel run (total 100)...
# Building estimator 26 of 100 for this parallel run (total 100)...
# Building estimator 27 of 100 for this parallel run (total 100)...
# Building estimator 28 of 100 for this parallel run (total 100)...
# Building estimator 29 of 100 for this parallel run (total 100)...
# Building estimator 30 of 100 for this parallel run (total 100)...
# Building estimator 31 of 100 for this parallel run (total 100)...
# Building estimator 32 of 100 for this parallel run (total 100)...
# Building estimator 33 of 100 for this parallel run (total 100)...
# Building estimator 34 of 100 for this parallel run (total 100)...
# Building estimator 35 of 100 for this parallel run (total 100)...
# Building estimator 36 of 100 for this parallel run (total 100)...
# Building estimator 37 of 100 for this parallel run (total 100)...
# Building estimator 38 of 100 for this parallel run (total 100)...
# Building estimator 39 of 100 for this parallel run (total 100)...
# Building estimator 40 of 100 for this parallel run (total 100)...
# Building estimator 41 of 100 for this parallel run (total 100)...
# Building estimator 42 of 100 for this parallel run (total 100)...
# Building estimator 43 of 100 for this parallel run (total 100)...
# Building estimator 44 of 100 for this parallel run (total 100)...
# Building estimator 45 of 100 for this parallel run (total 100)...
# Building estimator 46 of 100 for this parallel run (total 100)...
# Building estimator 47 of 100 for this parallel run (total 100)...
# Building estimator 48 of 100 for this parallel run (total 100)...
# Building estimator 49 of 100 for this parallel run (total 100)...
# Building estimator 50 of 100 for this parallel run (total 100)...
# Building estimator 51 of 100 for this parallel run (total 100)...
# Building estimator 52 of 100 for this parallel run (total 100)...
# Building estimator 53 of 100 for this parallel run (total 100)...
# Building estimator 54 of 100 for this parallel run (total 100)...
# Building estimator 55 of 100 for this parallel run (total 100)...
# Building estimator 56 of 100 for this parallel run (total 100)...
# Building estimator 57 of 100 for this parallel run (total 100)...
# Building estimator 58 of 100 for this parallel run (total 100)...
# Building estimator 59 of 100 for this parallel run (total 100)...
# Building estimator 60 of 100 for this parallel run (total 100)...
# Building estimator 61 of 100 for this parallel run (total 100)...
# Building estimator 62 of 100 for this parallel run (total 100)...
# Building estimator 63 of 100 for this parallel run (total 100)...
# Building estimator 64 of 100 for this parallel run (total 100)...
# Building estimator 65 of 100 for this parallel run (total 100)...
# Building estimator 66 of 100 for this parallel run (total 100)...
# Building estimator 67 of 100 for this parallel run (total 100)...
# Building estimator 68 of 100 for this parallel run (total 100)...
# Building estimator 69 of 100 for this parallel run (total 100)...
# Building estimator 70 of 100 for this parallel run (total 100)...
# Building estimator 71 of 100 for this parallel run (total 100)...
# Building estimator 72 of 100 for this parallel run (total 100)...
# Building estimator 73 of 100 for this parallel run (total 100)...
# Building estimator 74 of 100 for this parallel run (total 100)...
# Building estimator 75 of 100 for this parallel run (total 100)...
# Building estimator 76 of 100 for this parallel run (total 100)...
# Building estimator 77 of 100 for this parallel run (total 100)...
# Building estimator 78 of 100 for this parallel run (total 100)...
# Building estimator 79 of 100 for this parallel run (total 100)...
# Building estimator 80 of 100 for this parallel run (total 100)...
# Building estimator 81 of 100 for this parallel run (total 100)...
# Building estimator 82 of 100 for this parallel run (total 100)...
# Building estimator 83 of 100 for this parallel run (total 100)...
# Building estimator 84 of 100 for this parallel run (total 100)...
# Building estimator 85 of 100 for this parallel run (total 100)...
# Building estimator 86 of 100 for this parallel run (total 100)...
# Building estimator 87 of 100 for this parallel run (total 100)...
# Building estimator 88 of 100 for this parallel run (total 100)...
# Building estimator 89 of 100 for this parallel run (total 100)...
# Building estimator 90 of 100 for this parallel run (total 100)...
# Building estimator 91 of 100 for this parallel run (total 100)...
# Building estimator 92 of 100 for this parallel run (total 100)...
# Building estimator 93 of 100 for this parallel run (total 100)...
# Building estimator 94 of 100 for this parallel run (total 100)...
# Building estimator 95 of 100 for this parallel run (total 100)...
# Building estimator 96 of 100 for this parallel run (total 100)...
# Building estimator 97 of 100 for this parallel run (total 100)...
# Building estimator 98 of 100 for this parallel run (total 100)...
# Building estimator 99 of 100 for this parallel run (total 100)...
# Building estimator 100 of 100 for this parallel run (total 100)...
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s finished
# BaggingRegressor(base_estimator=DecisionTreeRegressor(max_depth=4),
#                  n_estimators=100, oob_score=True, random_state=410, verbose=2)

# %%
model_bag.score(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# 0.8579095655185303

# %%
model_bag.oob_score_
# Out:
# 0.791283592806648

# %%
y_pred_bag = model_bag.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
rmse_test_bag = np.sqrt(mean_squared_error(y_test, y_pred_bag))
print(model_bag.score(X_test,y_test))    
SSE = np.sum((y_pred_bag-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_bag = 1 - SSE/SST
print("Test RMSE Bag : ", rmse_test_bag)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 Bag: ", r2_test_bag)
# Out:
# 0.8274052641522022
# Test RMSE Bag :  0.47808922851600333
# Test SSE :  52.57094139729627
# Test SST :  304.65279984436444
# Test R2 Bag:  0.827439821908242
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %% [markdown]
# #### Random Forest

# %%
max_depths = np.linspace(1, 15, 15, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
   dt = RandomForestRegressor(max_depth=max_depth)
   dt.fit(X_train, y_train)
   train_pred = dt.predict(X_train)
   rmse_train_dt = np.sqrt(mean_squared_error(y_train, train_pred))
   SSE = np.sum((train_pred-y_train)**2)
   SST = np.sum((y_train-np.mean(y_train))**2)
   r2_train_dt = 1 - SSE/SST
   train_results.append(r2_train_dt)

   test_pred = dt.predict(X_test)
   rmse_test_dt = np.sqrt(mean_squared_error(y_test, test_pred))
   SSE = np.sum((test_pred -y_test)**2)
   SST = np.sum((y_test-np.mean(y_test))**2)
   r2_test_dt = 1 - SSE/SST
   test_results.append(r2_test_dt)
   
from matplotlib.legend_handler import HandlerLine2D
line1 = plt.plot(max_depths, train_results, 'b')
line2 = plt.plot(max_depths, test_results, 'r')
plt.ylabel('R2 score')
plt.xlabel('Tree depth')
plt.title('Depth vs R2 Score')
plt.show()

# %%
train_results = []
test_results = []
list_nb_trees =  [10, 20, 40, 60, 80, 100,120,140,160,180,200,250,300]

for nb_trees in list_nb_trees:
    rf = RandomForestRegressor(n_estimators=nb_trees)
    rf.fit(X_train, y_train)
    

    train_results.append(mean_squared_error(y_train, rf.predict(X_train)))
    #test_results.append(mean_squared_error(y_test, rf.predict(X_test)))
line1, = plt.plot(list_nb_trees, train_results, color="r", label="Training Score")
#line2, = plt.plot(list_nb_trees, test_results, color="g", label="Testing Score")

plt.ylabel('MSE')
plt.xlabel('n_estimators')
plt.show()

# %%
train_results = []
test_results = []
list_nb_trees =  [10, 20, 40, 60, 80, 100,120,140,160,180,200,250,300]

for nb_trees in list_nb_trees:
    rf = RandomForestRegressor(n_estimators=nb_trees)
    rf.fit(X_train, y_train)
    

    #train_results.append(mean_squared_error(y_train, rf.predict(X_train)))
    test_results.append(mean_squared_error(y_test, rf.predict(X_test)))
#line1, = plt.plot(list_nb_trees, train_results, color="r", label="Training Score")
line2, = plt.plot(list_nb_trees, test_results, color="g", label="Testing Score")

plt.ylabel('MSE')
plt.xlabel('n_estimators')
plt.show()

# %%
model_rf = RandomForestRegressor(n_estimators=150,max_features=4,random_state=10,oob_score=True,verbose=2,max_depth=3)

# %%
model_rf.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 150
# building tree 2 of 150
# building tree 3 of 150
# building tree 4 of 150
# building tree 5 of 150
# building tree 6 of 150
# building tree 7 of 150
# building tree 8 of 150
# building tree 9 of 150
# building tree 10 of 150
# building tree 11 of 150
# building tree 12 of 150
# building tree 13 of 150
# building tree 14 of 150
# building tree 15 of 150
# building tree 16 of 150
# building tree 17 of 150
# building tree 18 of 150
# building tree 19 of 150
# building tree 20 of 150
# building tree 21 of 150
# building tree 22 of 150
# building tree 23 of 150
# building tree 24 of 150
# building tree 25 of 150
# building tree 26 of 150
# building tree 27 of 150
# building tree 28 of 150
# building tree 29 of 150
# building tree 30 of 150
# building tree 31 of 150
# building tree 32 of 150
# building tree 33 of 150
# building tree 34 of 150
# building tree 35 of 150
# building tree 36 of 150
# building tree 37 of 150
# building tree 38 of 150
# building tree 39 of 150
# building tree 40 of 150
# building tree 41 of 150
# building tree 42 of 150
# building tree 43 of 150
# building tree 44 of 150
# building tree 45 of 150
# building tree 46 of 150
# building tree 47 of 150
# building tree 48 of 150
# building tree 49 of 150
# building tree 50 of 150
# building tree 51 of 150
# building tree 52 of 150
# building tree 53 of 150
# building tree 54 of 150
# building tree 55 of 150
# building tree 56 of 150
# building tree 57 of 150
# building tree 58 of 150
# building tree 59 of 150
# building tree 60 of 150
# building tree 61 of 150
# building tree 62 of 150
# building tree 63 of 150
# building tree 64 of 150
# building tree 65 of 150
# building tree 66 of 150
# building tree 67 of 150
# building tree 68 of 150
# building tree 69 of 150
# building tree 70 of 150
# building tree 71 of 150
# building tree 72 of 150
# building tree 73 of 150
# building tree 74 of 150
# building tree 75 of 150
# building tree 76 of 150
# building tree 77 of 150
# building tree 78 of 150
# building tree 79 of 150
# building tree 80 of 150
# building tree 81 of 150
# building tree 82 of 150
# building tree 83 of 150
# building tree 84 of 150
# building tree 85 of 150
# building tree 86 of 150
# building tree 87 of 150
# building tree 88 of 150
# building tree 89 of 150
# building tree 90 of 150
# building tree 91 of 150
# building tree 92 of 150
# building tree 93 of 150
# building tree 94 of 150
# building tree 95 of 150
# building tree 96 of 150
# building tree 97 of 150
# building tree 98 of 150
# building tree 99 of 150
# building tree 100 of 150
# building tree 101 of 150
# building tree 102 of 150
# building tree 103 of 150
# building tree 104 of 150
# building tree 105 of 150
# building tree 106 of 150
# building tree 107 of 150
# building tree 108 of 150
# building tree 109 of 150
# building tree 110 of 150
# building tree 111 of 150
# building tree 112 of 150
# building tree 113 of 150
# building tree 114 of 150
# building tree 115 of 150
# building tree 116 of 150
# building tree 117 of 150
# building tree 118 of 150
# building tree 119 of 150
# building tree 120 of 150
# building tree 121 of 150
# building tree 122 of 150
# building tree 123 of 150
# building tree 124 of 150
# building tree 125 of 150
# building tree 126 of 150
# building tree 127 of 150
# building tree 128 of 150
# building tree 129 of 150
# building tree 130 of 150
# building tree 131 of 150
# building tree 132 of 150
# building tree 133 of 150
# building tree 134 of 150
# building tree 135 of 150
# building tree 136 of 150
# building tree 137 of 150
# building tree 138 of 150
# building tree 139 of 150
# building tree 140 of 150
# building tree 141 of 150
# building tree 142 of 150
# building tree 143 of 150
# building tree 144 of 150
# building tree 145 of 150
# building tree 146 of 150
# building tree 147 of 150
# building tree 148 of 150
# building tree 149 of 150
# building tree 150 of 150
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.3s finished
# RandomForestRegressor(max_depth=3, max_features=4, n_estimators=150,
#                       oob_score=True, random_state=10, verbose=2)

# %%
model_rf.score(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# 0.7968043221848135

# %%
model_rf.feature_importances_
# Out:
# array([0.43834886, 0.05833549, 0.05321505, 0.3285758 , 0.06772668,
#        0.04355194, 0.01024619])

# %%
data = pd.Series(model_rf.feature_importances_,index=X_train.columns)

# %%
data.sort_values(ascending=True,inplace=True)

# %%
data.plot.barh()
# Out:
# <AxesSubplot:>

# %%
y_pred_rf = model_rf.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished

# %%
rmse_test_rf1 = np.sqrt(mean_squared_error(y_test, y_pred_rf))
print(model_rf.score(X_test,y_test))   
SSE = np.sum((y_pred_rf-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_rf1 = 1 - SSE/SST
print("Test RMSE RF1 : ", rmse_test_rf1)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 RF1: ", r2_test_rf1)
# Out:
# 0.7866178808658746
# Test RMSE RF1 :  0.5315868120916518
# Test SSE :  64.994443921646
# Test SST :  304.65279984436444
# Test R2 RF1:  0.7866606052698377
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_estimators':[100,120,150],'max_depth': [1,2,3,4],'max_features': [1,2,3,4]}

# %%
tune_model = GridSearchCV(model_rf, parameters,cv=5)

# %%
tune_model.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 42 of 120
# building tree 43 of 120
# building tree 44 of 120
# building tree 45 of 120
# building tree 46 of 120
# building tree 47 of 120
# building tree 48 of 120
# building tree 49 of 120
# building tree 50 of 120
# building tree 51 of 120
# building tree 52 of 120
# building tree 53 of 120
# building tree 54 of 120
# building tree 55 of 120
# building tree 56 of 120
# building tree 57 of 120
# building tree 58 of 120
# building tree 59 of 120
# building tree 60 of 120
# building tree 61 of 120
# building tree 62 of 120
# building tree 63 of 120
# building tree 64 of 120
# building tree 65 of 120
# building tree 66 of 120
# building tree 67 of 120
# building tree 68 of 120
# building tree 69 of 120
# building tree 70 of 120
# building tree 71 of 120
# building tree 72 of 120
# building tree 73 of 120
# building tree 74 of 120
# building tree 75 of 120
# building tree 76 of 120
# building tree 77 of 120
# building tree 78 of 120
# building tree 79 of 120
# building tree 80 of 120
# building tree 81 of 120
# building tree 82 of 120
# building tree 83 of 120
# building tree 84 of 120
# building tree 85 of 120
# building tree 86 of 120
# building tree 87 of 120
# building tree 88 of 120
# building tree 89 of 120
# building tree 90 of 120
# building tree 91 of 120
# building tree 92 of 120
# building tree 93 of 120
# building tree 94 of 120
# building tree 95 of 120
# building tree 96 of 120
# building tree 97 of 120
# building tree 98 of 120
# building tree 99 of 120
# building tree 100 of 120
# building tree 101 of 120
# building tree 102 of 120
# building tree 103 of 120
# building tree 104 of 120
# building tree 105 of 120
# building tree 106 of 120
# building tree 107 of 120
# building tree 108 of 120
# building tree 109 of 120
# building tree 110 of 120
# building tree 111 of 120
# building tree 112 of 120
# building tree 113 of 120
# building tree 114 of 120
# building tree 115 of 120
# building tree 116 of 120
# building tree 117 of 120
# building tree 118 of 120
# building tree 119 of 120
# building tree 120 of 120
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:    0.2s finished
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(max_depth=3, max_features=4,
#                                              n_estimators=150, oob_score=True,
#                                              random_state=10, verbose=2),
#              param_grid={'max_depth': [1, 2, 3, 4],
#                          'max_features': [1, 2, 3, 4],
#                          'n_estimators': [100, 120, 150]})

# %%
tune_model.best_params_
# Out:
# {'max_depth': 4, 'max_features': 4, 'n_estimators': 120}

# %%
tune_model.score(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:    0.0s finished
# 0.8478542234847608

# %%
y_pred_cv = tune_model.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:    0.0s finished

# %%
rmse_test_rf2= np.sqrt(mean_squared_error(y_test, y_pred_cv))
print(tune_model.score(X_test,y_test))    
SSE = np.sum((y_pred_cv-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_rf2 = 1 - SSE/SST
print("Test RMSE RF2 : ", rmse_test_rf2)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 RF2: ", r2_test_rf2)
# Out:
# 0.8197820049675759
# Test RMSE RF2 :  0.48853340253459265
# Test SSE :  54.89292364016606
# Test SST :  304.65279984436444
# Test R2 RF2:  0.8198180890895841
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:    0.0s finished

# %% [markdown]
# #### Boosting

# %%
train_results = []
test_results = []
list_nb_trees =  [10, 20, 40, 60, 80, 100,120,140,160,180,200,250,300]

for nb_trees in list_nb_trees:
    rf = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=nb_trees)
    rf.fit(X_train, y_train)
    

    train_results.append(mean_squared_error(y_train, rf.predict(X_train)))
    #test_results.append(mean_squared_error(y_test, rf.predict(X_test)))
line1, = plt.plot(list_nb_trees, train_results, color="r", label="Training Score")
#line2, = plt.plot(list_nb_trees, test_results, color="g", label="Testing Score")

plt.ylabel('MSE')
plt.xlabel('n_estimators')
plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
train_results = []
test_results = []
list_nb_trees =  [10, 20, 40, 60, 80, 100,120,140,160,180,200,250,300]

for nb_trees in list_nb_trees:
    rf = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=nb_trees)
    rf.fit(X_train, y_train)
    

    #train_results.append(mean_squared_error(y_train, rf.predict(X_train)))
    test_results.append(mean_squared_error(y_test, rf.predict(X_test)))
#line1, = plt.plot(list_nb_trees, train_results, color="r", label="Training Score")
line2, = plt.plot(list_nb_trees, test_results, color="g", label="Testing Score")

plt.ylabel('MSE')
plt.xlabel('n_estimators')
plt.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
model_xgb = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=50)

# %%
model_xgb.fit(X_train,y_train)
model_xgb.score(X_train,y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# 0.9976774549452986

# %%
y_preds = model_xgb.predict(X_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
rmse_test_bost1 = np.sqrt(mean_squared_error(y_test, y_preds))
print(model_xgb.score(X_test,y_test))    
SSE = np.sum((y_preds-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_bost1 = 1 - SSE/SST
print("Test RMSE Bost1: ", rmse_test_bost1)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 Bost1: ", r2_test_bost1)
# Out:
# 0.8431231111864174
# Test RMSE Bost1:  0.45580036660198425
# Test SSE :  47.78341406473575
# Test SST :  304.65279984436444
# Test R2 Bost1:  0.8431545218388063
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
param_grid = {'max_depth':np.arange(1,4),'learning_rate':[0.1,0.01,0.001],'n_estimators':[100,120,150]}

# %%
tune_model1 = GridSearchCV(model_xgb,param_grid)

# %%
tune_model1.fit(X_train,y_train);
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
tune_model1.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 120}

# %%
tune_model1.best_score_
# Out:
# 0.8064277853589006

# %%
model_xgb_cv = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=100, max_depth = 3, learning_rate = 0.1)

# %%
model_xgb_cv.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
model_xgb_cv.score(X_train,y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# 0.9298301822772628

# %%
y_preds_cv = model_xgb_cv.predict(X_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
rmse_test_bost2 = np.sqrt(mean_squared_error(y_test, y_preds_cv))
print(model_xgb_cv.score(X_test,y_test))    
SSE = np.sum((y_preds_cv-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_bost2 = 1 - SSE/SST
print("Test RMSE Bost2: ", rmse_test_bost2)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 Bost2: ", r2_test_bost2)
# Out:
# 0.8508309809468082
# Test RMSE Bost2:  0.4444618638417585
# Test SSE :  45.43566013422868
# Test SST :  304.65279984436444
# Test R2 Bost2:  0.8508608482920885
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %% [markdown]
# ### KNN

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
model_knn = KNeighborsRegressor()   # n_neighbors:  (default = 5)

# %%
model_knn.fit(X_train_scaled,y_train)
model_knn.score(X_train_scaled,y_train)
# Out:
# 0.901286946752312

# %%
y_pred_test = model_knn.predict(X_test_scaled)
rmse_test_knn = np.sqrt(mean_squared_error(y_test, y_pred_test))
print(model_knn.score(X_test_scaled,y_test))    
SSE = np.sum((y_pred_test-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_knn = 1 - SSE/SST
print("Test RMSE LR : ", rmse_test_knn)
print("Test SSE : ", SSE)
print("Test SST : ", SST)

print("Test R2 LR: ", r2_test_knn)
# Out:
# 0.8290772280646961
# Test RMSE LR :  0.47576791427510834
# Test SSE :  52.061674898347974
# Test SST :  304.65279984436444
# Test R2 LR:  0.8291114510520031

# %%
from sklearn.metrics import mean_squared_error 
from math import sqrt
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train_scaled, y_train)  #fit the model
    pred=model.predict(X_test_scaled) #make prediction on test set
    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.5793517806350706
# RMSE value for k=  2 is: 0.5067653762754164
# RMSE value for k=  3 is: 0.48848470409466815
# RMSE value for k=  4 is: 0.4781966571057939
# RMSE value for k=  5 is: 0.47576791427510834
# RMSE value for k=  6 is: 0.4810773725743514
# RMSE value for k=  7 is: 0.4836360777832209
# RMSE value for k=  8 is: 0.4945738691963731
# RMSE value for k=  9 is: 0.49596344153858934
# RMSE value for k=  10 is: 0.500516990435239
# RMSE value for k=  11 is: 0.5074942229853482
# RMSE value for k=  12 is: 0.5070916938033055
# RMSE value for k=  13 is: 0.5043002267227342
# RMSE value for k=  14 is: 0.5077076019296568
# RMSE value for k=  15 is: 0.511735117998933
# RMSE value for k=  16 is: 0.5192315344691624
# RMSE value for k=  17 is: 0.5232189029975143
# RMSE value for k=  18 is: 0.5192620200645945
# RMSE value for k=  19 is: 0.5225714418886714
# RMSE value for k=  20 is: 0.5216649348187268

# %%
#plotting the rmse values against k values
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()
# Out:
# <AxesSubplot:>

# %%
#hypertuning 
# Use cross validation for selecting optimum value of 'k'
parameter = {'n_neighbors':[1,2,3,4]}

# %%
model_knn_tune = GridSearchCV(model_knn, parameter, cv=5)

# %%
model_knn_tune.fit(X_train_scaled,y_train)
model_knn_tune.score(X_train_scaled,y_train)
# Out:
# 0.9322835556009816

# %%
model_knn_tune.best_params_
# Out:
# {'n_neighbors': 3}

# %%
y_pred_test = model_knn_tune.predict(X_test_scaled)
rmse_test_knn_tune = np.sqrt(mean_squared_error(y_test, y_pred_test))
print(model_knn_tune.score(X_test_scaled,y_test))    
SSE = np.sum((y_pred_test-y_test)**2)
SST = np.sum((y_test-np.mean(y_train))**2)
r2_test_knn_tune = 1 - SSE/SST
print("Test RMSE LR : ", rmse_test_knn_tune)
print("Test SSE : ", SSE)
print("Test SST : ", SST)
print("Test R2 LR: ", r2_test_knn_tune)
# Out:
# 0.8198179324916038
# Test RMSE LR :  0.48848470409466815
# Test SSE :  54.88198041092477
# Test SST :  304.65279984436444
# Test R2 LR:  0.8198540094200286

# %% [markdown]
# ### Results

# %%
MODEL_NAME = ['model_lr','model_rfe','model_dt','model_bag','model_rf','tune_model','model_xgb','model_xgb_cv','model_knn','model_knn_tune']
RMSE = [rmse_test_lr,rmse_test_rfe,rmse_test_dt,rmse_test_bag,rmse_test_rf1,rmse_test_rf2,rmse_test_bost1,rmse_test_bost2,rmse_test_knn,rmse_test_knn_tune]
R_square = [r2_test_lr,r2_test_rfe,r2_test_dt,r2_test_bag,r2_test_rf1,r2_test_rf2,r2_test_bost1,r2_test_bost2,r2_test_knn,r2_test_knn_tune]
Score = [model_lr.score(X_train,y_train),model_rfe.score(X_train_rfe,y_train),model_dt.score(X_train,y_train),model_bag.score(X_train,y_train),model_rf.score(X_train,y_train),
        tune_model.score(X_train,y_train),model_xgb.score(X_train,y_train),model_xgb_cv.score(X_train,y_train),model_knn.score(X_train_scaled,y_train),model_knn_tune.score(X_train_scaled,y_train)]
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:    0.0s finished
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning:
#
# Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption

# %%
list_of_tuples = list(zip(MODEL_NAME, RMSE,R_square,Score)) 
list_of_tuples
# Out:
# [('model_lr', 0.5625757163871621, 0.7610623290810103, 0.7615489766065676),
#  ('model_rfe', 0.5785938068519235, 0.7472621866444779, 0.7304564074131231),
#  ('model_dt', 0.43299867474112197, 0.8584262415314726, 0.8083850384524076),
#  ('model_bag', 0.47808922851600333, 0.827439821908242, 0.8579095655185303),
#  ('model_rf', 0.5315868120916518, 0.7866606052698377, 0.7968043221848135),
#  ('tune_model', 0.48853340253459265, 0.8198180890895841, 0.8478542234847608),
#  ('model_xgb', 0.45580036660198425, 0.8431545218388063, 0.9976774549452986),
#  ('model_xgb_cv', 0.4444618638417585, 0.8508608482920885, 0.9298301822772628),
#  ('model_knn', 0.47576791427510834, 0.8291114510520031, 0.901286946752312),
#  ('model_knn_tune',
#   0.48848470409466815,
#   0.8198540094200286,
#   0.9322835556009816)]

# %%
Results = pd.DataFrame(list_of_tuples,
                  columns = ['MODEL_NAME', 'RMSE','R_Square_Test','Score']
                  )

# %%
Results['Difference'] = Results['Score'] - Results['R_Square_Test']
Results
# Out:
#        MODEL_NAME      RMSE  R_Square_Test     Score  Difference
# 0        model_lr  0.562576       0.761062  0.761549    0.000487
# 1       model_rfe  0.578594       0.747262  0.730456   -0.016806
# 2        model_dt  0.432999       0.858426  0.808385   -0.050041
# 3       model_bag  0.478089       0.827440  0.857910    0.030470
# 4        model_rf  0.531587       0.786661  0.796804    0.010144
# 5      tune_model  0.488533       0.819818  0.847854    0.028036
# 6       model_xgb  0.455800       0.843155  0.997677    0.154523
# 7    model_xgb_cv  0.444462       0.850861  0.929830    0.078969
# 8       model_knn  0.475768       0.829111  0.901287    0.072175
# 9  model_knn_tune  0.488485       0.819854  0.932284    0.112430

# %% [markdown]
# # Model Deployment

# %%
X_test.head()
# Out:
#      economy_(gdp_per_capita)   family  region  health_(life_expectancy)  \
# 143                   0.06940  0.77265       8                   0.29707
# 603                   0.26200  0.90800       8                   0.40200
# 218                   1.13062  1.04993       1                   0.63104
# 195                   1.05266  0.83309       4                   0.61804
# 486                   1.27000  1.52500       9                   0.88400
#
#      freedom  trust_(government_corruption)  generosity
# 143  0.47692                        0.15639     0.19387
# 603  0.22100                        0.04900     0.15500
# 218  0.29091                        0.17457     0.13942
# 195  0.21006                        0.16157     0.07044
# 486  0.64500                        0.14200     0.37600

# %%
X_test.columns
# Out:
# Index(['economy_(gdp_per_capita)', 'family', 'region',
#        'health_(life_expectancy)', 'freedom', 'trust_(government_corruption)',
#        'generosity'],
#       dtype='object')

# %%
y_test.head()
# Out:
# 143    3.845
# 603    3.774
# 218    5.802
# 195    6.355
# 486    6.627
# Name: happiness_score, dtype: float64

# %%
import pickle
pickle.dump(model_dt, open('model_final.pkl','wb'))

# %%
model = pickle.load(open('model_final.pkl','rb'))    # row 1
print(model.predict([[0.06940,	0.77265,	8,	0.29707,	0.47692,	0.15639,	0.19387]]))
# Out:
# [4.09680282]

# %%
model = pickle.load(open('model_final.pkl','rb'))    # row 2
print(model.predict([[0.26200,	0.90800,	8,	0.40200,	0.22100,	0.04900,	0.15500]]))
# Out:
# [4.09680282]

# %%
model = pickle.load(open('model_final.pkl','rb'))    # row 3
print(model.predict([[1.13062,	1.04993,	1,	0.63104,	0.29091,	0.17457,	0.13942]]))
# Out:
# [5.2511613]

# %%
model = pickle.load(open('model_final.pkl','rb'))    # row 4
print(model.predict([[1.05266,	0.83309,	4,	0.61804,	0.21006,	0.16157,	0.07044]]))
# Out:
# [4.94664913]

# %%
model = pickle.load(open('model_final.pkl','rb'))   # row 5
print(model.predict([[1.27000,	1.52500,	9,	0.88400,	0.64500,	0.14200,	0.37600]]))
# Out:
# [7.38391304]
